# %% [markdown]
# ## EDA : On Weather & Pollution Data:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the dataset from the specified path
Weather = pd.read_csv("https://climasphere-vk5q.onrender.com/download/downloadCSV")
Weather.head()
# Out:
#   Country CountryCode          State StateCode       City   CityID  Latitude  \
# 0   India          IN  Uttar Pradesh        UP   Varanasi  1253573   25.3176
# 1   India          IN        Gujarat        GJ  Ahmedabad  1279233   23.0225
# 2   India          IN  Uttar Pradesh        UP     Kanpur  1267995   26.4499
# 3   India          IN         Kerala        KL      Kochi  1267990    9.9312
# 4   India          IN      Rajasthan        RJ     Jaipur  1269515   26.9124
#
#    Longitude WeatherCondition WeatherDescription  ...     NO    NO2     O3  \
# 0    82.9739           Clouds         few clouds  ...  10.52  25.15  46.08
# 1    72.5714            Clear          clear sky  ...  16.75  17.17  73.82
# 2    80.3319           Clouds         few clouds  ...  16.62  57.64  36.54
# 3    76.2673            Clear          clear sky  ...  17.40  28.46  25.33
# 4    75.7873           Clouds         few clouds  ...   1.93  38.14  72.64
#
#      SO2    PM25    PM10    NH3              CreatedAt              UpdatedAt  \
# 0   9.56  154.76  224.40  12.37  1/1/2025, 12:00:00 pm  1/1/2025, 12:00:00 pm
# 1   7.46   42.93   63.11  14.77  6/1/2025, 12:00:00 pm  6/1/2025, 12:00:00 pm
# 2  13.68  175.23  280.37   1.61  6/1/2025, 12:00:00 pm  6/1/2025, 12:00:00 pm
# 3  22.20   29.12   43.10   4.08  6/1/2025, 12:00:00 pm  6/1/2025, 12:00:00 pm
# 4  19.81   89.88  121.34   8.11  7/1/2025, 12:00:00 pm  7/1/2025, 12:00:00 pm
#
#         Source
# 0  OpenWeather
# 1  OpenWeather
# 2  OpenWeather
# 3  OpenWeather
# 4  OpenWeather
#
# [5 rows x 36 columns]

# %%
Weather_Data = Weather.copy()

# %%
Weather_Data
# Out:
#       Country CountryCode           State StateCode       City   CityID  \
# 0       India          IN   Uttar Pradesh        UP   Varanasi  1253573
# 1       India          IN         Gujarat        GJ  Ahmedabad  1279233
# 2       India          IN   Uttar Pradesh        UP     Kanpur  1267995
# 3       India          IN          Kerala        KL      Kochi  1267990
# 4       India          IN       Rajasthan        RJ     Jaipur  1269515
# ...       ...         ...             ...       ...        ...      ...
# 11315   India          IN         Gujarat        GJ      Surat  1255364
# 11316   India          IN  Madhya Pradesh        MP     Bhopal  1275817
# 11317   India          IN          Kerala        KL      Kochi  1267990
# 11318   India          IN             Goa        GA        Goa  1256523
# 11319   India          IN       Karnataka        KA     Mysuru  1262321
#
#        Latitude  Longitude WeatherCondition WeatherDescription  ...     NO  \
# 0       25.3176    82.9739           Clouds         few clouds  ...  10.52
# 1       23.0225    72.5714            Clear          clear sky  ...  16.75
# 2       26.4499    80.3319           Clouds         few clouds  ...  16.62
# 3        9.9312    76.2673            Clear          clear sky  ...  17.40
# 4       26.9124    75.7873           Clouds         few clouds  ...   1.93
# ...         ...        ...              ...                ...  ...    ...
# 11315   21.1702    72.8311             Rain         light rain  ...  12.97
# 11316   23.2599    77.4126           Clouds         few clouds  ...  13.01
# 11317    9.9312    76.2673             Rain         light rain  ...  18.23
# 11318   15.2993    74.1240     Thunderstorm       thunderstorm  ...  17.26
# 11319   12.2958    76.6394           Clouds         few clouds  ...   8.51
#
#          NO2     O3    SO2    PM25    PM10    NH3               CreatedAt  \
# 0      25.15  46.08   9.56  154.76  224.40  12.37   1/1/2025, 12:00:00 pm
# 1      17.17  73.82   7.46   42.93   63.11  14.77   6/1/2025, 12:00:00 pm
# 2      57.64  36.54  13.68  175.23  280.37   1.61   6/1/2025, 12:00:00 pm
# 3      28.46  25.33  22.20   29.12   43.10   4.08   6/1/2025, 12:00:00 pm
# 4      38.14  72.64  19.81   89.88  121.34   8.11   7/1/2025, 12:00:00 pm
# ...      ...    ...    ...     ...     ...    ...                     ...
# 11315  47.86  70.60  15.77   30.68   48.47   4.75  19/7/2026, 12:00:00 pm
# 11316  16.99  77.33  21.51   51.30   77.98  14.45  19/7/2026, 12:00:00 pm
# 11317   9.70  15.02  25.21   10.60   15.16   1.58  19/7/2026, 12:00:00 pm
# 11318  58.44  47.55   5.51   38.86   54.40   2.56  19/7/2026, 12:00:00 pm
# 11319  45.42  62.75   7.91   21.07   29.29  11.89  19/7/2026, 12:00:00 pm
#
#                     UpdatedAt       Source
# 0       1/1/2025, 12:00:00 pm  OpenWeather
# 1       6/1/2025, 12:00:00 pm  OpenWeather
# 2       6/1/2025, 12:00:00 pm  OpenWeather
# 3       6/1/2025, 12:00:00 pm  OpenWeather
# 4       7/1/2025, 12:00:00 pm  OpenWeather
# ...                       ...          ...
# 11315  19/7/2026, 12:00:00 pm  OpenWeather
# 11316  19/7/2026, 12:00:00 pm  OpenWeather
# 11317  19/7/2026, 12:00:00 pm  OpenWeather
# 11318  19/7/2026, 12:00:00 pm  OpenWeather
# 11319  19/7/2026, 12:00:00 pm  OpenWeather
#
# [11320 rows x 36 columns]

# %%
Weather_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11320 entries, 0 to 11319
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             11320 non-null  object
#  1   CountryCode         11320 non-null  object
#  2   State               11320 non-null  object
#  3   StateCode           11320 non-null  object
#  4   City                11320 non-null  object
#  5   CityID              11320 non-null  int64
#  6   Latitude            11320 non-null  float64
#  7   Longitude           11320 non-null  float64
#  8   WeatherCondition    11320 non-null  object
#  9   WeatherDescription  11320 non-null  object
#  10  WeatherCode         11320 non-null  int64
#  11  Temperature         11320 non-null  float64
#  12  FeelsLike           11320 non-null  float64
#  13  TempMin             11320 non-null  int64
#  14  TempMax             11320 non-null  int64
#  15  Pressure            11320 non-null  int64
#  16  Humidity            11320 non-null  int64
#  17  SeaLevel            11320 non-null  int64
#  18  GroundLevel         11320 non-null  int64
#  19  WindSpeed           11320 non-null  float64
#  20  WindDirection       11320 non-null  int64
#  21  WindGust            11320 non-null  float64
#  22  CloudCoverage       11320 non-null  int64
#  23  Visibility          11320 non-null  int64
#  24  AQI                 11320 non-null  int64
#  25  CO                  11320 non-null  float64
#  26  NO                  11320 non-null  float64
#  27  NO2                 11320 non-null  float64
#  28  O3                  11320 non-null  float64
#  29  SO2                 11320 non-null  float64
#  30  PM25                11320 non-null  float64
#  31  PM10                11320 non-null  float64
#  32  NH3                 11320 non-null  float64
#  33  CreatedAt           11320 non-null  object
#  34  UpdatedAt           11320 non-null  object
#  35  Source              11320 non-null  object
# dtypes: float64(14), int64(12), object(10)
# memory usage: 3.1+ MB

# %%
Weather_Data.describe()
# Out:
#              CityID      Latitude     Longitude   WeatherCode   Temperature  \
# count  1.132000e+04  11320.000000  11320.000000  11320.000000  11320.000000
# mean   1.266262e+06     20.357720     78.299435    694.825795     27.350351
# std    8.021943e+03      5.440117      4.211659    187.121959      6.845345
# min    1.252783e+06      9.931200     72.571400    211.000000      6.150000
# 25%    1.259872e+06     16.863575     75.371475    701.000000     23.170000
# 50%    1.266362e+06     21.158000     77.503600    800.000000     27.910000
# 75%    1.273722e+06     25.386725     80.485475    800.000000     31.950000
# max    1.279233e+06     28.613900     88.363900    801.000000     44.890000
#
#           FeelsLike       TempMin       TempMax      Pressure      Humidity  \
# count  11320.000000  11320.000000  11320.000000  11320.000000  11320.000000
# mean      27.354462     21.028445     33.680212   1010.031007     61.095760
# std        6.936267      6.246510      5.488331      8.641438     19.211049
# min        5.100000      6.000000     21.000000    995.000000     15.000000
# 25%       23.067500     17.000000     30.000000   1003.000000     46.000000
# 50%       27.885000     22.000000     33.000000   1010.000000     62.000000
# 75%       32.020000     26.000000     38.000000   1017.000000     77.000000
# max       45.690000     30.000000     45.000000   1025.000000    100.000000
#
#        ...    Visibility           AQI            CO            NO  \
# count  ...  11320.000000  11320.000000  11320.000000  11320.000000
# mean   ...   6690.230565    112.714399    853.318502     10.049286
# std    ...   2051.308648     63.540140    378.165374      5.777580
# min    ...    507.000000     15.000000    200.130000      0.000000
# 25%    ...   5192.750000     66.000000    525.152500      5.070000
# 50%    ...   6792.000000    100.000000    857.580000     10.020000
# 75%    ...   8399.000000    143.000000   1181.072500     15.090000
# max    ...   9999.000000    398.000000   1499.720000     20.000000
#
#                 NO2            O3           SO2          PM25          PM10  \
# count  11320.000000  11320.000000  11320.000000  11320.000000  11320.000000
# mean      32.837641     45.183099     16.015483     56.293654     78.843342
# std       15.851608     20.204755      8.100821     32.572229     46.254210
# min        5.000000     10.000000      2.000000      6.150000      8.330000
# 25%       19.240000     27.927500      8.960000     32.760000     45.260000
# 50%       33.140000     45.035000     16.180000     49.560000     69.230000
# 75%       46.572500     62.610000     23.000000     71.520000    100.480000
# max       60.000000     79.990000     30.000000    226.860000    328.820000
#
#                 NH3
# count  11320.000000
# mean       7.976877
# std        4.039016
# min        1.000000
# 25%        4.480000
# 50%        7.950000
# 75%       11.472500
# max       15.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# ### Step 2: Data Cleaning

# %%
# Convert CreatedAt & UpdatedAt strings to datetime
Weather_Data['CreatedAt'] = pd.to_datetime(Weather_Data['CreatedAt'], format='%d/%m/%Y, %I:%M:%S %p')
Weather_Data['UpdatedAt'] = pd.to_datetime(Weather_Data['UpdatedAt'], format='%d/%m/%Y, %I:%M:%S %p')
Weather_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11320 entries, 0 to 11319
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             11320 non-null  object
#  1   CountryCode         11320 non-null  object
#  2   State               11320 non-null  object
#  3   StateCode           11320 non-null  object
#  4   City                11320 non-null  object
#  5   CityID              11320 non-null  int64
#  6   Latitude            11320 non-null  float64
#  7   Longitude           11320 non-null  float64
#  8   WeatherCondition    11320 non-null  object
#  9   WeatherDescription  11320 non-null  object
#  10  WeatherCode         11320 non-null  int64
#  11  Temperature         11320 non-null  float64
#  12  FeelsLike           11320 non-null  float64
#  13  TempMin             11320 non-null  int64
#  14  TempMax             11320 non-null  int64
#  15  Pressure            11320 non-null  int64
#  16  Humidity            11320 non-null  int64
#  17  SeaLevel            11320 non-null  int64
#  18  GroundLevel         11320 non-null  int64
#  19  WindSpeed           11320 non-null  float64
#  20  WindDirection       11320 non-null  int64
#  21  WindGust            11320 non-null  float64
#  22  CloudCoverage       11320 non-null  int64
#  23  Visibility          11320 non-null  int64
#  24  AQI                 11320 non-null  int64
#  25  CO                  11320 non-null  float64
#  26  NO                  11320 non-null  float64
#  27  NO2                 11320 non-null  float64
#  28  O3                  11320 non-null  float64
#  29  SO2                 11320 non-null  float64
#  30  PM25                11320 non-null  float64
#  31  PM10                11320 non-null  float64
#  32  NH3                 11320 non-null  float64
#  33  CreatedAt           11320 non-null  datetime64[ns]
#  34  UpdatedAt           11320 non-null  datetime64[ns]
#  35  Source              11320 non-null  object
# dtypes: datetime64[ns](2), float64(14), int64(12), object(8)
# memory usage: 3.1+ MB

# %%
Weather_Data
# Out:
#       Country CountryCode           State StateCode       City   CityID  \
# 0       India          IN   Uttar Pradesh        UP   Varanasi  1253573
# 1       India          IN         Gujarat        GJ  Ahmedabad  1279233
# 2       India          IN   Uttar Pradesh        UP     Kanpur  1267995
# 3       India          IN          Kerala        KL      Kochi  1267990
# 4       India          IN       Rajasthan        RJ     Jaipur  1269515
# ...       ...         ...             ...       ...        ...      ...
# 11315   India          IN         Gujarat        GJ      Surat  1255364
# 11316   India          IN  Madhya Pradesh        MP     Bhopal  1275817
# 11317   India          IN          Kerala        KL      Kochi  1267990
# 11318   India          IN             Goa        GA        Goa  1256523
# 11319   India          IN       Karnataka        KA     Mysuru  1262321
#
#        Latitude  Longitude WeatherCondition WeatherDescription  ...     NO  \
# 0       25.3176    82.9739           Clouds         few clouds  ...  10.52
# 1       23.0225    72.5714            Clear          clear sky  ...  16.75
# 2       26.4499    80.3319           Clouds         few clouds  ...  16.62
# 3        9.9312    76.2673            Clear          clear sky  ...  17.40
# 4       26.9124    75.7873           Clouds         few clouds  ...   1.93
# ...         ...        ...              ...                ...  ...    ...
# 11315   21.1702    72.8311             Rain         light rain  ...  12.97
# 11316   23.2599    77.4126           Clouds         few clouds  ...  13.01
# 11317    9.9312    76.2673             Rain         light rain  ...  18.23
# 11318   15.2993    74.1240     Thunderstorm       thunderstorm  ...  17.26
# 11319   12.2958    76.6394           Clouds         few clouds  ...   8.51
#
#          NO2     O3    SO2    PM25    PM10    NH3           CreatedAt  \
# 0      25.15  46.08   9.56  154.76  224.40  12.37 2025-01-01 12:00:00
# 1      17.17  73.82   7.46   42.93   63.11  14.77 2025-01-06 12:00:00
# 2      57.64  36.54  13.68  175.23  280.37   1.61 2025-01-06 12:00:00
# 3      28.46  25.33  22.20   29.12   43.10   4.08 2025-01-06 12:00:00
# 4      38.14  72.64  19.81   89.88  121.34   8.11 2025-01-07 12:00:00
# ...      ...    ...    ...     ...     ...    ...                 ...
# 11315  47.86  70.60  15.77   30.68   48.47   4.75 2026-07-19 12:00:00
# 11316  16.99  77.33  21.51   51.30   77.98  14.45 2026-07-19 12:00:00
# 11317   9.70  15.02  25.21   10.60   15.16   1.58 2026-07-19 12:00:00
# 11318  58.44  47.55   5.51   38.86   54.40   2.56 2026-07-19 12:00:00
# 11319  45.42  62.75   7.91   21.07   29.29  11.89 2026-07-19 12:00:00
#
#                 UpdatedAt       Source
# 0     2025-01-01 12:00:00  OpenWeather
# 1     2025-01-06 12:00:00  OpenWeather
# 2     2025-01-06 12:00:00  OpenWeather
# 3     2025-01-06 12:00:00  OpenWeather
# 4     2025-01-07 12:00:00  OpenWeather
# ...                   ...          ...
# 11315 2026-07-19 12:00:00  OpenWeather
# 11316 2026-07-19 12:00:00  OpenWeather
# 11317 2026-07-19 12:00:00  OpenWeather
# 11318 2026-07-19 12:00:00  OpenWeather
# 11319 2026-07-19 12:00:00  OpenWeather
#
# [11320 rows x 36 columns]

# %%
# Extract Only Date from 'Record Created At' for further analysis
Weather_Data['Date'] = Weather_Data['UpdatedAt'].dt.date
Weather_Data
# Out:
#       Country CountryCode           State StateCode       City   CityID  \
# 0       India          IN   Uttar Pradesh        UP   Varanasi  1253573
# 1       India          IN         Gujarat        GJ  Ahmedabad  1279233
# 2       India          IN   Uttar Pradesh        UP     Kanpur  1267995
# 3       India          IN          Kerala        KL      Kochi  1267990
# 4       India          IN       Rajasthan        RJ     Jaipur  1269515
# ...       ...         ...             ...       ...        ...      ...
# 11315   India          IN         Gujarat        GJ      Surat  1255364
# 11316   India          IN  Madhya Pradesh        MP     Bhopal  1275817
# 11317   India          IN          Kerala        KL      Kochi  1267990
# 11318   India          IN             Goa        GA        Goa  1256523
# 11319   India          IN       Karnataka        KA     Mysuru  1262321
#
#        Latitude  Longitude WeatherCondition WeatherDescription  ...    NO2  \
# 0       25.3176    82.9739           Clouds         few clouds  ...  25.15
# 1       23.0225    72.5714            Clear          clear sky  ...  17.17
# 2       26.4499    80.3319           Clouds         few clouds  ...  57.64
# 3        9.9312    76.2673            Clear          clear sky  ...  28.46
# 4       26.9124    75.7873           Clouds         few clouds  ...  38.14
# ...         ...        ...              ...                ...  ...    ...
# 11315   21.1702    72.8311             Rain         light rain  ...  47.86
# 11316   23.2599    77.4126           Clouds         few clouds  ...  16.99
# 11317    9.9312    76.2673             Rain         light rain  ...   9.70
# 11318   15.2993    74.1240     Thunderstorm       thunderstorm  ...  58.44
# 11319   12.2958    76.6394           Clouds         few clouds  ...  45.42
#
#           O3    SO2    PM25    PM10    NH3           CreatedAt  \
# 0      46.08   9.56  154.76  224.40  12.37 2025-01-01 12:00:00
# 1      73.82   7.46   42.93   63.11  14.77 2025-01-06 12:00:00
# 2      36.54  13.68  175.23  280.37   1.61 2025-01-06 12:00:00
# 3      25.33  22.20   29.12   43.10   4.08 2025-01-06 12:00:00
# 4      72.64  19.81   89.88  121.34   8.11 2025-01-07 12:00:00
# ...      ...    ...     ...     ...    ...                 ...
# 11315  70.60  15.77   30.68   48.47   4.75 2026-07-19 12:00:00
# 11316  77.33  21.51   51.30   77.98  14.45 2026-07-19 12:00:00
# 11317  15.02  25.21   10.60   15.16   1.58 2026-07-19 12:00:00
# 11318  47.55   5.51   38.86   54.40   2.56 2026-07-19 12:00:00
# 11319  62.75   7.91   21.07   29.29  11.89 2026-07-19 12:00:00
#
#                 UpdatedAt       Source        Date
# 0     2025-01-01 12:00:00  OpenWeather  2025-01-01
# 1     2025-01-06 12:00:00  OpenWeather  2025-01-06
# 2     2025-01-06 12:00:00  OpenWeather  2025-01-06
# 3     2025-01-06 12:00:00  OpenWeather  2025-01-06
# 4     2025-01-07 12:00:00  OpenWeather  2025-01-07
# ...                   ...          ...         ...
# 11315 2026-07-19 12:00:00  OpenWeather  2026-07-19
# 11316 2026-07-19 12:00:00  OpenWeather  2026-07-19
# 11317 2026-07-19 12:00:00  OpenWeather  2026-07-19
# 11318 2026-07-19 12:00:00  OpenWeather  2026-07-19
# 11319 2026-07-19 12:00:00  OpenWeather  2026-07-19
#
# [11320 rows x 37 columns]

# %%
Weather_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11320 entries, 0 to 11319
# Data columns (total 37 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             11320 non-null  object
#  1   CountryCode         11320 non-null  object
#  2   State               11320 non-null  object
#  3   StateCode           11320 non-null  object
#  4   City                11320 non-null  object
#  5   CityID              11320 non-null  int64
#  6   Latitude            11320 non-null  float64
#  7   Longitude           11320 non-null  float64
#  8   WeatherCondition    11320 non-null  object
#  9   WeatherDescription  11320 non-null  object
#  10  WeatherCode         11320 non-null  int64
#  11  Temperature         11320 non-null  float64
#  12  FeelsLike           11320 non-null  float64
#  13  TempMin             11320 non-null  int64
#  14  TempMax             11320 non-null  int64
#  15  Pressure            11320 non-null  int64
#  16  Humidity            11320 non-null  int64
#  17  SeaLevel            11320 non-null  int64
#  18  GroundLevel         11320 non-null  int64
#  19  WindSpeed           11320 non-null  float64
#  20  WindDirection       11320 non-null  int64
#  21  WindGust            11320 non-null  float64
#  22  CloudCoverage       11320 non-null  int64
#  23  Visibility          11320 non-null  int64
#  24  AQI                 11320 non-null  int64
#  25  CO                  11320 non-null  float64
#  26  NO                  11320 non-null  float64
#  27  NO2                 11320 non-null  float64
#  28  O3                  11320 non-null  float64
#  29  SO2                 11320 non-null  float64
#  30  PM25                11320 non-null  float64
#  31  PM10                11320 non-null  float64
#  32  NH3                 11320 non-null  float64
#  33  CreatedAt           11320 non-null  datetime64[ns]
#  34  UpdatedAt           11320 non-null  datetime64[ns]
#  35  Source              11320 non-null  object
#  36  Date                11320 non-null  object
# dtypes: datetime64[ns](2), float64(14), int64(12), object(9)
# memory usage: 3.2+ MB

# %%
Weather_Data.describe()
# Out:
#              CityID      Latitude     Longitude   WeatherCode   Temperature  \
# count  1.132000e+04  11320.000000  11320.000000  11320.000000  11320.000000
# mean   1.266262e+06     20.357720     78.299435    694.825795     27.350351
# min    1.252783e+06      9.931200     72.571400    211.000000      6.150000
# 25%    1.259872e+06     16.863575     75.371475    701.000000     23.170000
# 50%    1.266362e+06     21.158000     77.503600    800.000000     27.910000
# 75%    1.273722e+06     25.386725     80.485475    800.000000     31.950000
# max    1.279233e+06     28.613900     88.363900    801.000000     44.890000
# std    8.021943e+03      5.440117      4.211659    187.121959      6.845345
#
#           FeelsLike       TempMin       TempMax      Pressure      Humidity  \
# count  11320.000000  11320.000000  11320.000000  11320.000000  11320.000000
# mean      27.354462     21.028445     33.680212   1010.031007     61.095760
# min        5.100000      6.000000     21.000000    995.000000     15.000000
# 25%       23.067500     17.000000     30.000000   1003.000000     46.000000
# 50%       27.885000     22.000000     33.000000   1010.000000     62.000000
# 75%       32.020000     26.000000     38.000000   1017.000000     77.000000
# max       45.690000     30.000000     45.000000   1025.000000    100.000000
# std        6.936267      6.246510      5.488331      8.641438     19.211049
#
#        ...            CO            NO           NO2            O3  \
# count  ...  11320.000000  11320.000000  11320.000000  11320.000000
# mean   ...    853.318502     10.049286     32.837641     45.183099
# min    ...    200.130000      0.000000      5.000000     10.000000
# 25%    ...    525.152500      5.070000     19.240000     27.927500
# 50%    ...    857.580000     10.020000     33.140000     45.035000
# 75%    ...   1181.072500     15.090000     46.572500     62.610000
# max    ...   1499.720000     20.000000     60.000000     79.990000
# std    ...    378.165374      5.777580     15.851608     20.204755
#
#                 SO2          PM25          PM10           NH3  \
# count  11320.000000  11320.000000  11320.000000  11320.000000
# mean      16.015483     56.293654     78.843342      7.976877
# min        2.000000      6.150000      8.330000      1.000000
# 25%        8.960000     32.760000     45.260000      4.480000
# 50%       16.180000     49.560000     69.230000      7.950000
# 75%       23.000000     71.520000    100.480000     11.472500
# max       30.000000    226.860000    328.820000     15.000000
# std        8.100821     32.572229     46.254210      4.039016
#
#                            CreatedAt                      UpdatedAt
# count                          11320                          11320
# mean   2025-10-10 23:44:44.098939904  2025-10-10 23:44:44.098939904
# min              2025-01-01 12:00:00            2025-01-01 12:00:00
# 25%              2025-05-22 12:00:00            2025-05-22 12:00:00
# 50%              2025-10-11 00:00:00            2025-10-11 00:00:00
# 75%              2026-03-01 12:00:00            2026-03-01 12:00:00
# max              2026-07-19 12:00:00            2026-07-19 12:00:00
# std                              NaN                            NaN
#
# [8 rows x 28 columns]

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# UpdatedAt             0
# Source                0
# Date                  0
# dtype: int64

# %% [markdown]
# ### Step 1: First quantify & visualize missingness

# %%
Weather_Data.head()
# Out:
#   Country CountryCode          State StateCode       City   CityID  Latitude  \
# 0   India          IN  Uttar Pradesh        UP   Varanasi  1253573   25.3176
# 1   India          IN        Gujarat        GJ  Ahmedabad  1279233   23.0225
# 2   India          IN  Uttar Pradesh        UP     Kanpur  1267995   26.4499
# 3   India          IN         Kerala        KL      Kochi  1267990    9.9312
# 4   India          IN      Rajasthan        RJ     Jaipur  1269515   26.9124
#
#    Longitude WeatherCondition WeatherDescription  ...    NO2     O3    SO2  \
# 0    82.9739           Clouds         few clouds  ...  25.15  46.08   9.56
# 1    72.5714            Clear          clear sky  ...  17.17  73.82   7.46
# 2    80.3319           Clouds         few clouds  ...  57.64  36.54  13.68
# 3    76.2673            Clear          clear sky  ...  28.46  25.33  22.20
# 4    75.7873           Clouds         few clouds  ...  38.14  72.64  19.81
#
#      PM25    PM10    NH3           CreatedAt           UpdatedAt       Source  \
# 0  154.76  224.40  12.37 2025-01-01 12:00:00 2025-01-01 12:00:00  OpenWeather
# 1   42.93   63.11  14.77 2025-01-06 12:00:00 2025-01-06 12:00:00  OpenWeather
# 2  175.23  280.37   1.61 2025-01-06 12:00:00 2025-01-06 12:00:00  OpenWeather
# 3   29.12   43.10   4.08 2025-01-06 12:00:00 2025-01-06 12:00:00  OpenWeather
# 4   89.88  121.34   8.11 2025-01-07 12:00:00 2025-01-07 12:00:00  OpenWeather
#
#          Date
# 0  2025-01-01
# 1  2025-01-06
# 2  2025-01-06
# 3  2025-01-06
# 4  2025-01-07
#
# [5 rows x 37 columns]

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# UpdatedAt             0
# Source                0
# Date                  0
# dtype: int64

# %% [markdown]
# ### Step 1: Remove duplicates if any

# %%
# Count duplicates if any
duplicate_count = Weather_Data.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
# Remove duplicates data in the dataset
Weather_Data = Weather_Data.drop_duplicates()

# %%
# Count duplicates if any
duplicate_count = Weather_Data.duplicated().sum()
print(f"After removing duplicates the number of duplicate rows is: {duplicate_count}")
# Out:
# After removing duplicates the number of duplicate rows is: 0

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# UpdatedAt             0
# Source                0
# Date                  0
# dtype: int64

# %% [markdown]
# ### Step 2: Fix Wind variables (time-aware)
# - Data Cleaning - Handling Missing Values Of 'Wind Speed (m/s)' Column Using Interpolation
# - Interpolation means estimating missing values that fall within the range of known values.
# - Then we will use time-based interpolation since our data is time-series data.

# %%
# Sort the data by City Name and Record Created At
Weather_Data = Weather_Data.sort_values(['City','UpdatedAt','Date'])
Weather_Data
# Out:
#       Country CountryCode           State StateCode           City   CityID  \
# 307     India          IN         Gujarat        GJ      Ahmedabad  1279233
# 289     India          IN         Gujarat        GJ      Ahmedabad  1279233
# 97      India          IN         Gujarat        GJ      Ahmedabad  1279233
# 203     India          IN         Gujarat        GJ      Ahmedabad  1279233
# 23      India          IN         Gujarat        GJ      Ahmedabad  1279233
# ...       ...         ...             ...       ...            ...      ...
# 11233   India          IN  Andhra Pradesh        AP  Visakhapatnam  1252783
# 11253   India          IN  Andhra Pradesh        AP  Visakhapatnam  1252783
# 11273   India          IN  Andhra Pradesh        AP  Visakhapatnam  1252783
# 11293   India          IN  Andhra Pradesh        AP  Visakhapatnam  1252783
# 11313   India          IN  Andhra Pradesh        AP  Visakhapatnam  1252783
#
#        Latitude  Longitude WeatherCondition WeatherDescription  ...    NO2  \
# 307     23.0225    72.5714            Clear          clear sky  ...  17.70
# 289     23.0225    72.5714            Clear          clear sky  ...  19.87
# 97      23.0225    72.5714            Clear          clear sky  ...   7.44
# 203     23.0225    72.5714            Clear          clear sky  ...  32.39
# 23      23.0225    72.5714            Clear          clear sky  ...  44.30
# ...         ...        ...              ...                ...  ...    ...
# 11233   17.6868    83.2185           Clouds         few clouds  ...  31.95
# 11253   17.6868    83.2185           Clouds         few clouds  ...  31.50
# 11273   17.6868    83.2185           Clouds         few clouds  ...   6.94
# 11293   17.6868    83.2185     Thunderstorm       thunderstorm  ...  46.69
# 11313   17.6868    83.2185             Rain         light rain  ...   5.52
#
#           O3    SO2   PM25    PM10    NH3           CreatedAt  \
# 307    37.25   9.68  77.40  111.46   3.83 2025-01-01 12:00:00
# 289    33.26  28.91  39.20   56.06  14.72 2025-01-02 12:00:00
# 97     20.31  15.33  96.25  115.50   3.13 2025-01-03 12:00:00
# 203    19.23  15.71  37.80   54.05   8.77 2025-01-04 12:00:00
# 23     25.05   4.77  62.22   89.60   6.80 2025-01-05 12:00:00
# ...      ...    ...    ...     ...    ...                 ...
# 11233  57.81  20.38  13.76   21.47   6.43 2026-07-15 12:00:00
# 11253  36.71  27.27  31.39   41.12   4.34 2026-07-16 12:00:00
# 11273  47.38  25.25  25.38   37.05   6.54 2026-07-17 12:00:00
# 11293  64.01  20.39  36.26   48.59   4.77 2026-07-18 12:00:00
# 11313  45.35   2.72  26.40   41.98  13.24 2026-07-19 12:00:00
#
#                 UpdatedAt       Source        Date
# 307   2025-01-01 12:00:00  OpenWeather  2025-01-01
# 289   2025-01-02 12:00:00  OpenWeather  2025-01-02
# 97    2025-01-03 12:00:00  OpenWeather  2025-01-03
# 203   2025-01-04 12:00:00  OpenWeather  2025-01-04
# 23    2025-01-05 12:00:00  OpenWeather  2025-01-05
# ...                   ...          ...         ...
# 11233 2026-07-15 12:00:00  OpenWeather  2026-07-15
# 11253 2026-07-16 12:00:00  OpenWeather  2026-07-16
# 11273 2026-07-17 12:00:00  OpenWeather  2026-07-17
# 11293 2026-07-18 12:00:00  OpenWeather  2026-07-18
# 11313 2026-07-19 12:00:00  OpenWeather  2026-07-19
#
# [11320 rows x 37 columns]

# %% [markdown]
# ### A) Now Handle Missing Values Of "Wind Speed"

# %%
# Find rows where 'Wind Speed (m/s)' is still missing
Weather_Data[Weather_Data['WindSpeed']
            .isnull()][['WeatherCondition', 'WeatherDescription', 'WindSpeed', 'City', 'Date', 'UpdatedAt']]
# Out:
# Empty DataFrame
# Columns: [WeatherCondition, WeatherDescription, WindSpeed, City, Date, UpdatedAt]
# Index: []

# %%
# See the 'Wind Speed (m/s)' column along with other relevant columns
Weather_Data[Weather_Data['WindSpeed']
            .notnull()][['WeatherCondition', 'WeatherDescription', 'WindSpeed', 'City', 'Date', 'UpdatedAt']]
# Out:
#       WeatherCondition WeatherDescription  WindSpeed           City  \
# 307              Clear          clear sky       3.92      Ahmedabad
# 289              Clear          clear sky       2.43      Ahmedabad
# 97               Clear          clear sky       2.41      Ahmedabad
# 203              Clear          clear sky       6.23      Ahmedabad
# 23               Clear          clear sky       1.78      Ahmedabad
# ...                ...                ...        ...            ...
# 11233           Clouds         few clouds       6.00  Visakhapatnam
# 11253           Clouds         few clouds       4.15  Visakhapatnam
# 11273           Clouds         few clouds       7.33  Visakhapatnam
# 11293     Thunderstorm       thunderstorm       6.86  Visakhapatnam
# 11313             Rain         light rain       7.73  Visakhapatnam
#
#              Date           UpdatedAt
# 307    2025-01-01 2025-01-01 12:00:00
# 289    2025-01-02 2025-01-02 12:00:00
# 97     2025-01-03 2025-01-03 12:00:00
# 203    2025-01-04 2025-01-04 12:00:00
# 23     2025-01-05 2025-01-05 12:00:00
# ...           ...                 ...
# 11233  2026-07-15 2026-07-15 12:00:00
# 11253  2026-07-16 2026-07-16 12:00:00
# 11273  2026-07-17 2026-07-17 12:00:00
# 11293  2026-07-18 2026-07-18 12:00:00
# 11313  2026-07-19 2026-07-19 12:00:00
#
# [11320 rows x 6 columns]

# %%
# Temporarily set datetime as index for time-based interpolation
Weather_Data = Weather_Data.set_index('UpdatedAt')

# %%
# Do Time-based interpolation with filling remaining NaNs with median
# Interpolation meaning filling the missing values in a time series data by estimating them based on the values before and after the missing 
# data points. In this case, we are using time-based interpolation to fill in the missing 'Wind Speed (m/s)' values for each city. 
# If there are still any missing values after interpolation, we will fill those with the median value of 'Wind Speed (m/s)' for that city.
Weather_Data['WindSpeed'] = (
    Weather_Data.groupby('City')['WindSpeed']
      .transform(lambda x: x.interpolate(method='time')
                            .fillna(x.median()))
)

# %%
# Restore DataFrame from index to get back its original structure
Weather_Data = Weather_Data.reset_index()

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Source                0
# Date                  0
# dtype: int64

# %%
Weather_Data['WindSpeed']
# Out:
# 0        3.92
# 1        2.43
# 2        2.41
# 3        6.23
# 4        1.78
#          ...
# 11315    6.00
# 11316    4.15
# 11317    7.33
# 11318    6.86
# 11319    7.73
# Name: WindSpeed, Length: 11320, dtype: float64

# %%
Weather_Data['WindSpeed'] = Weather_Data['WindSpeed'].round(2)
Weather_Data['WindSpeed']
# Out:
# 0        3.92
# 1        2.43
# 2        2.41
# 3        6.23
# 4        1.78
#          ...
# 11315    6.00
# 11316    4.15
# 11317    7.33
# 11318    6.86
# 11319    7.73
# Name: WindSpeed, Length: 11320, dtype: float64

# %% [markdown]
# ### B) Now Handle Missing Values Of 'Wind Direction (deg)' Column Using circular interpolation

# %%
# Find rows where 'Wind Direction (degrees)' is still missing
Weather_Data[Weather_Data['WindDirection']
            .isnull()][['WeatherCondition', 'WeatherDescription', 'WindDirection', 'City', 'Date', 'UpdatedAt']]
# Out:
# Empty DataFrame
# Columns: [WeatherCondition, WeatherDescription, WindDirection, City, Date, UpdatedAt]
# Index: []

# %%
# See the 'Wind Direction (degrees)' column along with other relevant columns
Weather_Data[Weather_Data['WindDirection']
            .notnull()][['WeatherCondition', 'WeatherDescription', 'WindDirection', 'City', 'Date', 'UpdatedAt']]
# Out:
#       WeatherCondition WeatherDescription  WindDirection           City  \
# 0                Clear          clear sky             89      Ahmedabad
# 1                Clear          clear sky              1      Ahmedabad
# 2                Clear          clear sky            234      Ahmedabad
# 3                Clear          clear sky            356      Ahmedabad
# 4                Clear          clear sky            267      Ahmedabad
# ...                ...                ...            ...            ...
# 11315           Clouds         few clouds            109  Visakhapatnam
# 11316           Clouds         few clouds             35  Visakhapatnam
# 11317           Clouds         few clouds            206  Visakhapatnam
# 11318     Thunderstorm       thunderstorm            246  Visakhapatnam
# 11319             Rain         light rain            348  Visakhapatnam
#
#              Date           UpdatedAt
# 0      2025-01-01 2025-01-01 12:00:00
# 1      2025-01-02 2025-01-02 12:00:00
# 2      2025-01-03 2025-01-03 12:00:00
# 3      2025-01-04 2025-01-04 12:00:00
# 4      2025-01-05 2025-01-05 12:00:00
# ...           ...                 ...
# 11315  2026-07-15 2026-07-15 12:00:00
# 11316  2026-07-16 2026-07-16 12:00:00
# 11317  2026-07-17 2026-07-17 12:00:00
# 11318  2026-07-18 2026-07-18 12:00:00
# 11319  2026-07-19 2026-07-19 12:00:00
#
# [11320 rows x 6 columns]

# %%
# Now Handle Missing Values Of 'Wind Direction (deg)' Column Using circular interpolation
# Since wind direction is a circular variable (0 degrees is the same as 360 degrees),
# we will use circular interpolation to fill the missing values.

def circular_mean(series):
    vals = series.dropna()
    if len(vals) == 0:
        return series.fillna(0)
    rad = np.deg2rad(vals)
    sin_sum = np.sin(rad).mean()
    cos_sum = np.cos(rad).mean()
    
    # Calculate mean angle
    # arctan2 returns angle in radians, convert back to degrees
    # For example, if arctan2 returns -90 degrees, we convert it to 270 degrees
    mean_angle = np.rad2deg(np.arctan2(sin_sum, cos_sum)) % 360
    return series.fillna(mean_angle)

Weather_Data['WindDirection'] = (
    Weather_Data.groupby(['City','Date'])['WindDirection']
      .transform(circular_mean)
)

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Source                0
# Date                  0
# dtype: int64

# %%
Weather_Data['WindDirection']
# Out:
# 0         89
# 1          1
# 2        234
# 3        356
# 4        267
#         ...
# 11315    109
# 11316     35
# 11317    206
# 11318    246
# 11319    348
# Name: WindDirection, Length: 11320, dtype: int64

# %%
Weather_Data['WindDirection'] = Weather_Data['WindDirection'].round(0)
Weather_Data['WindDirection']
# Out:
# 0         89
# 1          1
# 2        234
# 3        356
# 4        267
#         ...
# 11315    109
# 11316     35
# 11317    206
# 11318    246
# 11319    348
# Name: WindDirection, Length: 11320, dtype: int64

# %% [markdown]
# ### Step 3: Fix Cloud Coverage using Weather Condition

# %%
# Find rows where 'Cloud Coverage (%)' is still missing
Weather_Data[Weather_Data['CloudCoverage']
            .isnull()][['WeatherCondition', 'WeatherDescription', 'CloudCoverage', 'City', 'Date', 'UpdatedAt']]
# Out:
# Empty DataFrame
# Columns: [WeatherCondition, WeatherDescription, CloudCoverage, City, Date, UpdatedAt]
# Index: []

# %%
# See the 'Cloud Coverage (%)' column along with other relevant columns
Weather_Data[Weather_Data['CloudCoverage']
            .notnull()][['WeatherCondition', 'WeatherDescription', 'CloudCoverage', 'City', 'Date', 'UpdatedAt']]
# Out:
#       WeatherCondition WeatherDescription  CloudCoverage           City  \
# 0                Clear          clear sky             15      Ahmedabad
# 1                Clear          clear sky              2      Ahmedabad
# 2                Clear          clear sky              2      Ahmedabad
# 3                Clear          clear sky             15      Ahmedabad
# 4                Clear          clear sky             11      Ahmedabad
# ...                ...                ...            ...            ...
# 11315           Clouds         few clouds             43  Visakhapatnam
# 11316           Clouds         few clouds             47  Visakhapatnam
# 11317           Clouds         few clouds             35  Visakhapatnam
# 11318     Thunderstorm       thunderstorm             92  Visakhapatnam
# 11319             Rain         light rain             83  Visakhapatnam
#
#              Date           UpdatedAt
# 0      2025-01-01 2025-01-01 12:00:00
# 1      2025-01-02 2025-01-02 12:00:00
# 2      2025-01-03 2025-01-03 12:00:00
# 3      2025-01-04 2025-01-04 12:00:00
# 4      2025-01-05 2025-01-05 12:00:00
# ...           ...                 ...
# 11315  2026-07-15 2026-07-15 12:00:00
# 11316  2026-07-16 2026-07-16 12:00:00
# 11317  2026-07-17 2026-07-17 12:00:00
# 11318  2026-07-18 2026-07-18 12:00:00
# 11319  2026-07-19 2026-07-19 12:00:00
#
# [11320 rows x 6 columns]

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Source                0
# Date                  0
# dtype: int64

# %%
# Step 1: City + Weather Condition median
Weather_Data['CloudCoverage'] = Weather_Data['CloudCoverage'].fillna(
    Weather_Data.groupby(['City','WeatherCondition'])['CloudCoverage']
                .transform('median')
)

# Step 2: City + Date median
Weather_Data['CloudCoverage'] = Weather_Data['CloudCoverage'].fillna(
    Weather_Data.groupby(['City','Date'])['CloudCoverage']
                .transform('median')
)

# Step 3: City median
Weather_Data['CloudCoverage'] = Weather_Data['CloudCoverage'].fillna(
    Weather_Data.groupby('City')['CloudCoverage']
                .transform('median')
)

# Step 4: Global median (final fallback)
Weather_Data['CloudCoverage'] = Weather_Data['CloudCoverage'].fillna(
    Weather_Data['CloudCoverage'].median()
)

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Source                0
# Date                  0
# dtype: int64

# %%
Weather_Data['CloudCoverage']
# Out:
# 0        15
# 1         2
# 2         2
# 3        15
# 4        11
#          ..
# 11315    43
# 11316    47
# 11317    35
# 11318    92
# 11319    83
# Name: CloudCoverage, Length: 11320, dtype: int64

# %%
Weather_Data['CloudCoverage'] = Weather_Data['CloudCoverage'].round(0)
Weather_Data['CloudCoverage']
# Out:
# 0        15
# 1         2
# 2         2
# 3        15
# 4        11
#          ..
# 11315    43
# 11316    47
# 11317    35
# 11318    92
# 11319    83
# Name: CloudCoverage, Length: 11320, dtype: int64

# %% [markdown]
# ### Step 4: Fix NO & NH₃

# %% [markdown]
# ### First :- Fix Only 'NO (µg/m³)'

# %%
# Find rows where 'NO (µg/m³)' is still missing
Weather_Data[Weather_Data['NO']
             .isnull()][['WeatherCondition', 'WeatherDescription', 'NO', 'City', 'Date', 'UpdatedAt']].sort_values('Date')
# Out:
# Empty DataFrame
# Columns: [WeatherCondition, WeatherDescription, NO, City, Date, UpdatedAt]
# Index: []

# %%
# See notnull 'NO (µg/m³)' column along with other relevant columns
Weather_Data[Weather_Data['NO']
             .notnull()][['WeatherCondition', 'WeatherDescription', 'NO', 'City', 'Date', 'UpdatedAt']].sort_values('Date')
# Out:
#       WeatherCondition WeatherDescription     NO           City        Date  \
# 0                Clear          clear sky   5.85      Ahmedabad  2025-01-01
# 5660             Clear          clear sky  19.73        Kolkata  2025-01-01
# 1698             Clear          clear sky  14.45        Chennai  2025-01-01
# 1132             Clear          clear sky   6.69         Bhopal  2025-01-01
# 8490            Clouds         few clouds  10.79          Patna  2025-01-01
# ...                ...                ...    ...            ...         ...
# 8489      Thunderstorm       thunderstorm   9.49         Nagpur  2026-07-19
# 9055      Thunderstorm       thunderstorm   7.59          Patna  2026-07-19
# 9621              Rain         light rain  14.19           Pune  2026-07-19
# 5093            Clouds         few clouds  13.32         Kanpur  2026-07-19
# 11319             Rain         light rain  10.17  Visakhapatnam  2026-07-19
#
#                 UpdatedAt
# 0     2025-01-01 12:00:00
# 5660  2025-01-01 12:00:00
# 1698  2025-01-01 12:00:00
# 1132  2025-01-01 12:00:00
# 8490  2025-01-01 12:00:00
# ...                   ...
# 8489  2026-07-19 12:00:00
# 9055  2026-07-19 12:00:00
# 9621  2026-07-19 12:00:00
# 5093  2026-07-19 12:00:00
# 11319 2026-07-19 12:00:00
#
# [11320 rows x 6 columns]

# %%
# Step 1: City + Weather Description median (First It will try to fill using City and Weather Description combination)
Weather_Data['NO'] = Weather_Data['NO'].fillna(
    Weather_Data.groupby(['City','WeatherDescription'])['NO']
                .transform('median')
)

# Step 2: City + Date median (Second It will try to fill using City and Date combination)
Weather_Data['NO'] = Weather_Data['NO'].fillna(
    Weather_Data.groupby(['City','Date'])['NO'].transform('median')
)

# Step 3: City only (Third It will try to fill using only City if still NaN)
Weather_Data['NO'] = Weather_Data['NO'].fillna(
    Weather_Data.groupby('City')['NO'].transform('median')
)

# Step 4: Global median (Finally It will fill remaining NaNs with overall median)
Weather_Data['NO'] = Weather_Data['NO'].fillna(
    Weather_Data['NO'].median()
)

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Source                0
# Date                  0
# dtype: int64

# %%
Weather_Data['NO']
# Out:
# 0         5.85
# 1        14.94
# 2         1.54
# 3        14.10
# 4         6.23
#          ...
# 11315     3.22
# 11316    11.54
# 11317     5.35
# 11318     5.10
# 11319    10.17
# Name: NO, Length: 11320, dtype: float64

# %%
Weather_Data['NO'] = Weather_Data['NO'].round(2)
Weather_Data['NO']
# Out:
# 0         5.85
# 1        14.94
# 2         1.54
# 3        14.10
# 4         6.23
#          ...
# 11315     3.22
# 11316    11.54
# 11317     5.35
# 11318     5.10
# 11319    10.17
# Name: NO, Length: 11320, dtype: float64

# %% [markdown]
# ### Second :- Fix Only 'NH₃ (µg/m³)'

# %%
# Find rows where 'NH₃ (µg/m³)' is still missing
Weather_Data[Weather_Data['NH3']
            .isnull()][['WeatherCondition', 'WeatherDescription', 'NH3', 'City', 'Date', 'UpdatedAt']].sort_values('Date')
# Out:
# Empty DataFrame
# Columns: [WeatherCondition, WeatherDescription, NH3, City, Date, UpdatedAt]
# Index: []

# %%
# See notnull 'NH₃ (µg/m³)' column along with other relevant columns
Weather_Data[Weather_Data['NH3']
             .notnull()][['WeatherCondition', 'WeatherDescription', 'NH3', 'City', 'Date', 'UpdatedAt']].sort_values('Date')
# Out:
#       WeatherCondition WeatherDescription    NH3           City        Date  \
# 0                Clear          clear sky   3.83      Ahmedabad  2025-01-01
# 5660             Clear          clear sky   4.75        Kolkata  2025-01-01
# 1698             Clear          clear sky   1.82        Chennai  2025-01-01
# 1132             Clear          clear sky  14.09         Bhopal  2025-01-01
# 8490            Clouds         few clouds   2.32          Patna  2025-01-01
# ...                ...                ...    ...            ...         ...
# 8489      Thunderstorm       thunderstorm   8.95         Nagpur  2026-07-19
# 9055      Thunderstorm       thunderstorm   8.84          Patna  2026-07-19
# 9621              Rain         light rain   8.35           Pune  2026-07-19
# 5093            Clouds         few clouds   9.66         Kanpur  2026-07-19
# 11319             Rain         light rain  13.24  Visakhapatnam  2026-07-19
#
#                 UpdatedAt
# 0     2025-01-01 12:00:00
# 5660  2025-01-01 12:00:00
# 1698  2025-01-01 12:00:00
# 1132  2025-01-01 12:00:00
# 8490  2025-01-01 12:00:00
# ...                   ...
# 8489  2026-07-19 12:00:00
# 9055  2026-07-19 12:00:00
# 9621  2026-07-19 12:00:00
# 5093  2026-07-19 12:00:00
# 11319 2026-07-19 12:00:00
#
# [11320 rows x 6 columns]

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Source                0
# Date                  0
# dtype: int64

# %%
# Step 1: City + Weather Description median (First It will try to fill using City and Weather Description combination)
Weather_Data['NH3'] = Weather_Data['NH3'].fillna(
    Weather_Data.groupby(['City','WeatherDescription'])['NH3']
                .transform('median')
)

# Step 2: City + Date median (Second It will try to fill using City and Date combination)
Weather_Data['NH3'] = Weather_Data['NH3'].fillna(
    Weather_Data.groupby(['City','Date'])['NH3'].transform('median')
)

# Step 3: City only (Third It will try to fill using only City if still NaN)
Weather_Data['NH3'] = Weather_Data['NH3'].fillna(
    Weather_Data.groupby('City')['NH3'].transform('median')
)

# Step 4: Global median (Finally It will fill remaining NaNs with overall median)
Weather_Data['NH3'] = Weather_Data['NH3'].fillna(
    Weather_Data['NH3'].median()
)

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Source                0
# Date                  0
# dtype: int64

# %%
Weather_Data['NH3']
# Out:
# 0         3.83
# 1        14.72
# 2         3.13
# 3         8.77
# 4         6.80
#          ...
# 11315     6.43
# 11316     4.34
# 11317     6.54
# 11318     4.77
# 11319    13.24
# Name: NH3, Length: 11320, dtype: float64

# %%
Weather_Data['NH3'] = Weather_Data['NH3'].round(2)
Weather_Data['NH3']
# Out:
# 0         3.83
# 1        14.72
# 2         3.13
# 3         8.77
# 4         6.80
#          ...
# 11315     6.43
# 11316     4.34
# 11317     6.54
# 11318     4.77
# 11319    13.24
# Name: NH3, Length: 11320, dtype: float64

# %%
# Count duplicates if any
duplicate_count = Weather_Data.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
Weather_Data
# Out:
#                 UpdatedAt Country CountryCode           State StateCode  \
# 0     2025-01-01 12:00:00   India          IN         Gujarat        GJ
# 1     2025-01-02 12:00:00   India          IN         Gujarat        GJ
# 2     2025-01-03 12:00:00   India          IN         Gujarat        GJ
# 3     2025-01-04 12:00:00   India          IN         Gujarat        GJ
# 4     2025-01-05 12:00:00   India          IN         Gujarat        GJ
# ...                   ...     ...         ...             ...       ...
# 11315 2026-07-15 12:00:00   India          IN  Andhra Pradesh        AP
# 11316 2026-07-16 12:00:00   India          IN  Andhra Pradesh        AP
# 11317 2026-07-17 12:00:00   India          IN  Andhra Pradesh        AP
# 11318 2026-07-18 12:00:00   India          IN  Andhra Pradesh        AP
# 11319 2026-07-19 12:00:00   India          IN  Andhra Pradesh        AP
#
#                 City   CityID  Latitude  Longitude WeatherCondition  ...  \
# 0          Ahmedabad  1279233   23.0225    72.5714            Clear  ...
# 1          Ahmedabad  1279233   23.0225    72.5714            Clear  ...
# 2          Ahmedabad  1279233   23.0225    72.5714            Clear  ...
# 3          Ahmedabad  1279233   23.0225    72.5714            Clear  ...
# 4          Ahmedabad  1279233   23.0225    72.5714            Clear  ...
# ...              ...      ...       ...        ...              ...  ...
# 11315  Visakhapatnam  1252783   17.6868    83.2185           Clouds  ...
# 11316  Visakhapatnam  1252783   17.6868    83.2185           Clouds  ...
# 11317  Visakhapatnam  1252783   17.6868    83.2185           Clouds  ...
# 11318  Visakhapatnam  1252783   17.6868    83.2185     Thunderstorm  ...
# 11319  Visakhapatnam  1252783   17.6868    83.2185             Rain  ...
#
#           NO    NO2     O3    SO2   PM25    PM10    NH3           CreatedAt  \
# 0       5.85  17.70  37.25   9.68  77.40  111.46   3.83 2025-01-01 12:00:00
# 1      14.94  19.87  33.26  28.91  39.20   56.06  14.72 2025-01-02 12:00:00
# 2       1.54   7.44  20.31  15.33  96.25  115.50   3.13 2025-01-03 12:00:00
# 3      14.10  32.39  19.23  15.71  37.80   54.05   8.77 2025-01-04 12:00:00
# 4       6.23  44.30  25.05   4.77  62.22   89.60   6.80 2025-01-05 12:00:00
# ...      ...    ...    ...    ...    ...     ...    ...                 ...
# 11315   3.22  31.95  57.81  20.38  13.76   21.47   6.43 2026-07-15 12:00:00
# 11316  11.54  31.50  36.71  27.27  31.39   41.12   4.34 2026-07-16 12:00:00
# 11317   5.35   6.94  47.38  25.25  25.38   37.05   6.54 2026-07-17 12:00:00
# 11318   5.10  46.69  64.01  20.39  36.26   48.59   4.77 2026-07-18 12:00:00
# 11319  10.17   5.52  45.35   2.72  26.40   41.98  13.24 2026-07-19 12:00:00
#
#             Source        Date
# 0      OpenWeather  2025-01-01
# 1      OpenWeather  2025-01-02
# 2      OpenWeather  2025-01-03
# 3      OpenWeather  2025-01-04
# 4      OpenWeather  2025-01-05
# ...            ...         ...
# 11315  OpenWeather  2026-07-15
# 11316  OpenWeather  2026-07-16
# 11317  OpenWeather  2026-07-17
# 11318  OpenWeather  2026-07-18
# 11319  OpenWeather  2026-07-19
#
# [11320 rows x 37 columns]

# %% [markdown]
# ### STEP 1: Ensure pollutant columns are numeric

# %%
# pollutant_columns = [
#     "CO", "NO", "NO2", "O3",
#     "SO2", "PM25", "PM10", "NH3"
# ]

# Weather_Data[pollutant_columns] = Weather_Data[pollutant_columns].apply(
#     pd.to_numeric, errors="coerce"
# )

# %% [markdown]
# ### STEP 2: Define CPCB AQI Breakpoints (CPCB – INDIA)

# %%
# AQI_BREAKPOINTS = {
#     "PM25": [(0,30,0,50),(31,60,51,100),(61,90,101,200),
#               (91,120,201,300),(121,250,301,400),(251,500,401,500)],

#     "PM10": [(0,50,0,50),(51,100,51,100),(101,250,101,200),
#              (251,350,201,300),(351,430,301,400),(431,600,401,500)],

#     "NO2": [(0,40,0,50),(41,80,51,100),(81,180,101,200),
#             (181,280,201,300),(281,400,301,400),(401,1000,401,500)],

#     "SO2": [(0,40,0,50),(41,80,51,100),(81,380,101,200),
#             (381,800,201,300),(801,1600,301,400),(1601,2000,401,500)],

#     "CO": [(0,1.0,0,50),(1.1,2.0,51,100),(2.1,10,101,200),
#            (10.1,17,201,300),(17.1,34,301,400),(34.1,50,401,500)],

#     "O3": [(0,50,0,50),(51,100,51,100),(101,168,101,200),
#            (169,208,201,300),(209,748,301,400),(749,1000,401,500)],

#     "NH3": [(0,200,0,50),(201,400,51,100),(401,800,101,200),
#             (801,1200,201,300),(1201,1800,301,400),(1801,3000,401,500)]
# }

# %% [markdown]
# ### STEP 3: Mapping

# %%
# COLUMN_MAP = {
#     "PM25": "PM25",
#     "PM10": "PM10",
#     "NO2": "NO2",
#     "SO2": "SO2",
#     "CO": "CO",
#     "O3": "O3",
#     "NH3": "NH3"
# }

# %% [markdown]
# ### STEP 4: Sub-AQI calculation

# %%
# # Sub-AQI calculation function
# def calculate_sub_aqi(pollutant, concentration):
#     if pd.isna(concentration):
#         return None

#     for bp_lo, bp_hi, i_lo, i_hi in AQI_BREAKPOINTS[pollutant]:
#         if bp_lo <= concentration <= bp_hi:
#             return round(
#                 ((i_hi - i_lo) / (bp_hi - bp_lo)) *
#                 (concentration - bp_lo) + i_lo
#             )
#     return None

# %% [markdown]
# ### STEP 6: Final AQI calculation

# %%
# # Final AQI calculation (dominant pollutant logic)
# def calculate_final_aqi(row):
#     sub_aqis = []

#     for pollutant, column in COLUMN_MAP.items():
#         value = row[column]
#         sub = calculate_sub_aqi(pollutant, value)
#         if sub is not None:
#             sub_aqis.append(sub)

#     if len(sub_aqis) < 3:   # CPCB minimum requirement
#         return None

#     return max(sub_aqis)

# %% [markdown]
# ### STEP 7: Create Final AQI column

# %%
# Weather_Data["Final_AQI"] = Weather_Data.apply(calculate_final_aqi, axis=1)

# %%
# Weather_Data["Final_AQI"]

# %% [markdown]
# ### STEP 8: AQI Category column

# %%
# def aqi_category(aqi):
#     if pd.isna(aqi): return None
#     if aqi <= 50: return "Good"
#     if aqi <= 100: return "Satisfactory"
#     if aqi <= 200: return "Moderate"
#     if aqi <= 300: return "Poor"
#     if aqi <= 400: return "Very Poor"
#     return "Severe"

# Weather_Data["AQI_Category"] = Weather_Data["Final_AQI"].apply(aqi_category)

# %% [markdown]
# ### STEP 9: Final check

# %%
# Weather_Data[["City", "Final_AQI", "AQI_Category"]]

# %% [markdown]
# ### Step 3: Descriptive Statistics

# %%
# Summary statistics for numerical columns
Weather_Data.describe()
# Out:
#                            UpdatedAt        CityID      Latitude  \
# count                          11320  1.132000e+04  11320.000000
# mean   2025-10-10 23:44:44.098939904  1.266262e+06     20.357720
# min              2025-01-01 12:00:00  1.252783e+06      9.931200
# 25%              2025-05-22 12:00:00  1.259872e+06     16.863575
# 50%              2025-10-11 00:00:00  1.266362e+06     21.158000
# 75%              2026-03-01 12:00:00  1.273722e+06     25.386725
# max              2026-07-19 12:00:00  1.279233e+06     28.613900
# std                              NaN  8.021943e+03      5.440117
#
#           Longitude   WeatherCode   Temperature     FeelsLike       TempMin  \
# count  11320.000000  11320.000000  11320.000000  11320.000000  11320.000000
# mean      78.299435    694.825795     27.350351     27.354462     21.028445
# min       72.571400    211.000000      6.150000      5.100000      6.000000
# 25%       75.371475    701.000000     23.170000     23.067500     17.000000
# 50%       77.503600    800.000000     27.910000     27.885000     22.000000
# 75%       80.485475    800.000000     31.950000     32.020000     26.000000
# max       88.363900    801.000000     44.890000     45.690000     30.000000
# std        4.211659    187.121959      6.845345      6.936267      6.246510
#
#             TempMax      Pressure  ...           AQI            CO  \
# count  11320.000000  11320.000000  ...  11320.000000  11320.000000
# mean      33.680212   1010.031007  ...    112.714399    853.318502
# min       21.000000    995.000000  ...     15.000000    200.130000
# 25%       30.000000   1003.000000  ...     66.000000    525.152500
# 50%       33.000000   1010.000000  ...    100.000000    857.580000
# 75%       38.000000   1017.000000  ...    143.000000   1181.072500
# max       45.000000   1025.000000  ...    398.000000   1499.720000
# std        5.488331      8.641438  ...     63.540140    378.165374
#
#                  NO           NO2            O3           SO2          PM25  \
# count  11320.000000  11320.000000  11320.000000  11320.000000  11320.000000
# mean      10.049286     32.837641     45.183099     16.015483     56.293654
# min        0.000000      5.000000     10.000000      2.000000      6.150000
# 25%        5.070000     19.240000     27.927500      8.960000     32.760000
# 50%       10.020000     33.140000     45.035000     16.180000     49.560000
# 75%       15.090000     46.572500     62.610000     23.000000     71.520000
# max       20.000000     60.000000     79.990000     30.000000    226.860000
# std        5.777580     15.851608     20.204755      8.100821     32.572229
#
#                PM10           NH3                      CreatedAt
# count  11320.000000  11320.000000                          11320
# mean      78.843342      7.976877  2025-10-10 23:44:44.098939904
# min        8.330000      1.000000            2025-01-01 12:00:00
# 25%       45.260000      4.480000            2025-05-22 12:00:00
# 50%       69.230000      7.950000            2025-10-11 00:00:00
# 75%      100.480000     11.472500            2026-03-01 12:00:00
# max      328.820000     15.000000            2026-07-19 12:00:00
# std       46.254210      4.039016                            NaN
#
# [8 rows x 28 columns]

# %%
# Unique cities & states
print("Unique cities:", Weather_Data['City'].nunique(), "\nUnique states:", Weather_Data['State'].nunique())
# Out:
# Unique cities: 20
# Unique states: 14

# %%
# Show the countries, states, and cities name in the dataset
Weather_Data[['Country', 'State', 'City']]
# Out:
#       Country           State           City
# 0       India         Gujarat      Ahmedabad
# 1       India         Gujarat      Ahmedabad
# 2       India         Gujarat      Ahmedabad
# 3       India         Gujarat      Ahmedabad
# 4       India         Gujarat      Ahmedabad
# ...       ...             ...            ...
# 11315   India  Andhra Pradesh  Visakhapatnam
# 11316   India  Andhra Pradesh  Visakhapatnam
# 11317   India  Andhra Pradesh  Visakhapatnam
# 11318   India  Andhra Pradesh  Visakhapatnam
# 11319   India  Andhra Pradesh  Visakhapatnam
#
# [11320 rows x 3 columns]

# %%
# Frequency of weather conditions
Weather_Data['WeatherCondition'].value_counts()
# Out:
# WeatherCondition
# Clear           5061
# Clouds          2614
# Rain            1669
# Thunderstorm    1052
# Mist             485
# Haze             190
# Heat Wave        108
# Cold Wave        100
# Dust              41
# Name: count, dtype: int64

# %%
Weather_Data.head(10)
# Out:
#             UpdatedAt Country CountryCode    State StateCode       City  \
# 0 2025-01-01 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 1 2025-01-02 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 2 2025-01-03 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 3 2025-01-04 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 4 2025-01-05 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 5 2025-01-06 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 6 2025-01-07 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 7 2025-01-08 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 8 2025-01-09 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 9 2025-01-10 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
#
#     CityID  Latitude  Longitude WeatherCondition  ...     NO    NO2     O3  \
# 0  1279233   23.0225    72.5714            Clear  ...   5.85  17.70  37.25
# 1  1279233   23.0225    72.5714            Clear  ...  14.94  19.87  33.26
# 2  1279233   23.0225    72.5714            Clear  ...   1.54   7.44  20.31
# 3  1279233   23.0225    72.5714            Clear  ...  14.10  32.39  19.23
# 4  1279233   23.0225    72.5714            Clear  ...   6.23  44.30  25.05
# 5  1279233   23.0225    72.5714            Clear  ...  16.75  17.17  73.82
# 6  1279233   23.0225    72.5714            Clear  ...  13.85  30.42  51.00
# 7  1279233   23.0225    72.5714            Clear  ...   1.11  42.90  54.60
# 8  1279233   23.0225    72.5714            Clear  ...  18.08  55.58  11.60
# 9  1279233   23.0225    72.5714            Clear  ...  14.96  57.35  78.51
#
#      SO2   PM25    PM10    NH3           CreatedAt       Source        Date
# 0   9.68  77.40  111.46   3.83 2025-01-01 12:00:00  OpenWeather  2025-01-01
# 1  28.91  39.20   56.06  14.72 2025-01-02 12:00:00  OpenWeather  2025-01-02
# 2  15.33  96.25  115.50   3.13 2025-01-03 12:00:00  OpenWeather  2025-01-03
# 3  15.71  37.80   54.05   8.77 2025-01-04 12:00:00  OpenWeather  2025-01-04
# 4   4.77  62.22   89.60   6.80 2025-01-05 12:00:00  OpenWeather  2025-01-05
# 5   7.46  42.93   63.11  14.77 2025-01-06 12:00:00  OpenWeather  2025-01-06
# 6  17.80  53.30   69.29   1.75 2025-01-07 12:00:00  OpenWeather  2025-01-07
# 7   2.08  59.22   78.76  10.44 2025-01-08 12:00:00  OpenWeather  2025-01-08
# 8  17.82  52.46   70.30   3.99 2025-01-09 12:00:00  OpenWeather  2025-01-09
# 9  19.94  46.11   68.24   5.98 2025-01-10 12:00:00  OpenWeather  2025-01-10
#
# [10 rows x 37 columns]

# %% [markdown]
# ### Step 4: Weather Analysis

# %% [markdown]
# ### Viz 1: Temperature distribution

# %%
# Here we visualize the temperature distribution using a histogram with a KDE overlay.
# Frequency represents how often each temperature range occurs in the dataset.
# kde stands for Kernel Density Estimate, which provides a smooth estimate of the distribution.
# kde=True adds the KDE line to the histogram.
sns.histplot(Weather_Data['Temperature'], kde=True)
plt.title("Temperature Distribution")
plt.xlabel("Temperature (°C)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Viz 2: Wind speed distribution

# %%
# Wind speed distribution
sns.histplot(Weather_Data['WindSpeed'])
plt.title("Wind Speed Distribution")
plt.xlabel("WindSpeed")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Viz 3: Average temperature vs Cloud Coverage

# %%
# Average temperature vs Cloud Coverage
avg_temp_by_cloud = Weather_Data.groupby('CloudCoverage')['Temperature'].mean()
sns.jointplot(
    data=Weather_Data,
    x='CloudCoverage',
    y=avg_temp_by_cloud,
    kind='scatter',
    color='b'
)
plt.suptitle('Cloud Coverage (%) vs. Avg. Temperature (°C)', y=1.02)
plt.show()

# %% [markdown]
# ### Viz 4.1: Time of count for each Weather condition

# %%
# Time of count for each Weather condition 
# kind='bar' specifies that we want a bar plot.
Weather_Data['WeatherCondition'].value_counts().plot(kind='bar', figsize=(10,5))
plt.title("Weather Condition Frequency")
plt.xlabel("Weather Condition")
plt.ylabel("Total Number of Times")
plt.show()

# %% [markdown]
# ### Viz 4.2: Top 5 cities with highest Haze days

# %%
# Find top 5 cities with highest Haze days
haze_days = Weather_Data[Weather_Data['WeatherCondition'] == 'Haze'].copy()
haze_days_count = haze_days.groupby('City').size().sort_values(ascending=False).head(10)
haze_days_count.plot(kind='bar', figsize=(10,5))
plt.title("Top 10 Cities with Highest Haze Days")
plt.xlabel("City")
plt.ylabel("Number of Haze Days")
plt.show()

# %% [markdown]
# ### Viz 4.3: "Pune" has Highest Haze Occurrence

# %%
Weather_Data
# Out:
#                 UpdatedAt Country CountryCode           State StateCode  \
# 0     2025-01-01 12:00:00   India          IN         Gujarat        GJ
# 1     2025-01-02 12:00:00   India          IN         Gujarat        GJ
# 2     2025-01-03 12:00:00   India          IN         Gujarat        GJ
# 3     2025-01-04 12:00:00   India          IN         Gujarat        GJ
# 4     2025-01-05 12:00:00   India          IN         Gujarat        GJ
# ...                   ...     ...         ...             ...       ...
# 11315 2026-07-15 12:00:00   India          IN  Andhra Pradesh        AP
# 11316 2026-07-16 12:00:00   India          IN  Andhra Pradesh        AP
# 11317 2026-07-17 12:00:00   India          IN  Andhra Pradesh        AP
# 11318 2026-07-18 12:00:00   India          IN  Andhra Pradesh        AP
# 11319 2026-07-19 12:00:00   India          IN  Andhra Pradesh        AP
#
#                 City   CityID  Latitude  Longitude WeatherCondition  ...  \
# 0          Ahmedabad  1279233   23.0225    72.5714            Clear  ...
# 1          Ahmedabad  1279233   23.0225    72.5714            Clear  ...
# 2          Ahmedabad  1279233   23.0225    72.5714            Clear  ...
# 3          Ahmedabad  1279233   23.0225    72.5714            Clear  ...
# 4          Ahmedabad  1279233   23.0225    72.5714            Clear  ...
# ...              ...      ...       ...        ...              ...  ...
# 11315  Visakhapatnam  1252783   17.6868    83.2185           Clouds  ...
# 11316  Visakhapatnam  1252783   17.6868    83.2185           Clouds  ...
# 11317  Visakhapatnam  1252783   17.6868    83.2185           Clouds  ...
# 11318  Visakhapatnam  1252783   17.6868    83.2185     Thunderstorm  ...
# 11319  Visakhapatnam  1252783   17.6868    83.2185             Rain  ...
#
#           NO    NO2     O3    SO2   PM25    PM10    NH3           CreatedAt  \
# 0       5.85  17.70  37.25   9.68  77.40  111.46   3.83 2025-01-01 12:00:00
# 1      14.94  19.87  33.26  28.91  39.20   56.06  14.72 2025-01-02 12:00:00
# 2       1.54   7.44  20.31  15.33  96.25  115.50   3.13 2025-01-03 12:00:00
# 3      14.10  32.39  19.23  15.71  37.80   54.05   8.77 2025-01-04 12:00:00
# 4       6.23  44.30  25.05   4.77  62.22   89.60   6.80 2025-01-05 12:00:00
# ...      ...    ...    ...    ...    ...     ...    ...                 ...
# 11315   3.22  31.95  57.81  20.38  13.76   21.47   6.43 2026-07-15 12:00:00
# 11316  11.54  31.50  36.71  27.27  31.39   41.12   4.34 2026-07-16 12:00:00
# 11317   5.35   6.94  47.38  25.25  25.38   37.05   6.54 2026-07-17 12:00:00
# 11318   5.10  46.69  64.01  20.39  36.26   48.59   4.77 2026-07-18 12:00:00
# 11319  10.17   5.52  45.35   2.72  26.40   41.98  13.24 2026-07-19 12:00:00
#
#             Source        Date
# 0      OpenWeather  2025-01-01
# 1      OpenWeather  2025-01-02
# 2      OpenWeather  2025-01-03
# 3      OpenWeather  2025-01-04
# 4      OpenWeather  2025-01-05
# ...            ...         ...
# 11315  OpenWeather  2026-07-15
# 11316  OpenWeather  2026-07-16
# 11317  OpenWeather  2026-07-17
# 11318  OpenWeather  2026-07-18
# 11319  OpenWeather  2026-07-19
#
# [11320 rows x 37 columns]

# %%
# Find out when "Bhopal" has Highest Haze Occurrence based on months name
bhopal_haze = Weather_Data[(Weather_Data['City'] == 'Bhopal') & (Weather_Data['WeatherCondition'] == 'Haze')].copy()
bhopal_haze['Month'] = pd.to_datetime(bhopal_haze['Date']).dt.month_name()
bhopal_haze_monthly = bhopal_haze.groupby('Month').size().sort_values(ascending=False)
bhopal_haze_monthly.plot(kind='bar', figsize=(10,5))
plt.title("Top Months with Highest Haze Occurrence in Bhopal")
plt.xlabel("Month")
plt.ylabel("Number of Haze Observations")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Viz 4.4: PM2.5 Levels on Haze vs Non-Haze Days (Pune)

# %%
bhopal_data = Weather_Data[Weather_Data['City'] == 'Bhopal'].copy()

bhopal_data['Haze_Flag'] = bhopal_data['WeatherCondition'].apply(
    lambda x: 'Haze' if x == 'Haze' else 'Non-Haze'
)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(
    data=bhopal_data,
    x='Haze_Flag',
    y='PM25',
    color='purple', 
)
plt.title('PM2.5 Levels on Haze vs Non-Haze Days (Bhopal)')
plt.xlabel('Haze Flag')
plt.ylabel('PM2.5')
plt.show()

# %% [markdown]
# ### Viz 4.5: Humidity (%) on Haze vs Non-Haze Days (Kolkata)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(
    data=bhopal_data,
    x='Haze_Flag',
    y='Humidity',
    color='lightblue'
)
plt.title('Humidity on Haze vs Non-Haze Days (Bhopal)')
plt.xlabel('')
plt.ylabel('Humidity')
plt.show()

# %% [markdown]
# ### Viz 4.6: HWind Speed (m/s) on Haze vs Non-Haze Days (Pune)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(
    data=bhopal_data,
    x='Haze_Flag',
    y='WindSpeed',
    color='lightgreen'
)
plt.title('Wind Speed on Haze vs Non-Haze Days (Bhopal)')
plt.xlabel('')
plt.ylabel('Wind Speed (m/s)')
plt.show()

# %% [markdown]
# ### Viz 5: Observations of Humidity (%) in Kolkata Over Time

# %%
# Find out the observations of Humidity (%) in Kolkata Over Time
kolkata_data = Weather_Data[(Weather_Data['City'] == 'Kolkata')].copy()
plt.figure(figsize=(20, 5))
sns.lineplot(x='Date', y='Humidity', data=kolkata_data, color='cyan')
plt.suptitle("Humidity (%) in Kolkata Over Time", y=1.02)
plt.show()

# %% [markdown]
# ### Viz 6: Observations of PM2.5 & PM10 Levels in Kolkata Over Time

# %%
# Find out the observations of PM2.5, PM10 Levels in Kolkata Over Time based on months
# Create Month column
kolkata_data['Month'] = pd.to_datetime(kolkata_data['Date']).dt.to_period('M').astype(str)

# Monthly averages
monthly_data = (kolkata_data.groupby('Month')[['PM25', 'PM10']].mean().reset_index())

plt.figure(figsize=(20, 5))
sns.lineplot(x='Month',y='PM25',data=monthly_data,color='lightcoral',label='PM2.5')
sns.lineplot(x='Month',y='PM10',data=monthly_data,color='darkblue',label='PM10')
plt.title("Monthly Average PM2.5 and PM10 Levels in Kolkata",fontsize=16)

plt.xlabel("Month")
plt.ylabel("Concentration (µg/m³)")
plt.xticks(rotation=45)
plt.legend(title='Pollutant')

plt.show()

# %% [markdown]
# ### Viz 7.1: Top 5 Hottest Cities by Average Temperature
# ### Viz 7.2: Top 5 Coldest Cities by Average Temperature

# %%
# Calculate average temperature per city
avg_temp_city = (Weather_Data.groupby('City', as_index=False)['Temperature'].mean())

# Top 5 hottest cities
top_5_hot = avg_temp_city.sort_values(by='Temperature', ascending=False).head(5)

# Top 5 coldest cities
top_5_cold = avg_temp_city.sort_values(by='Temperature', ascending=True).head(5)

# Create subplots
fig, axes = plt.subplots(2, 1, figsize=(10, 15))

# ____Hot cities plot___
ax1 = sns.barplot(
    data=top_5_hot,
    x='City',
    y='Temperature',
    color='red',
    ax=axes[0], 
    width=0.5
)
axes[0].set_title('Top 5 Hottest Cities by Average Temperature', fontsize=16)
axes[0].set_xlabel('City', fontsize=14)
axes[0].set_ylabel('Average Temperature (°C)', fontsize=14)
axes[0].bar_label(ax1.containers[0], fmt='%.1f°C', fontsize=12)

axes[0].tick_params(axis='x', labelsize=12)
axes[0].tick_params(axis='y', labelsize=12)

# ___Cold cities plot____
ax2 = sns.barplot(
    data=top_5_cold,
    x='City',
    y='Temperature',
    color='blue',
    ax=axes[1],
    width=0.5
)
axes[1].set_title('Top 5 Coldest Cities by Average Temperature', fontsize=16)
axes[1].set_xlabel('City', fontsize=14)
axes[1].set_ylabel('Average Temperature (°C)', fontsize=14)
axes[1].bar_label(ax2.containers[0], fmt='%.1f°C', fontsize=12)

axes[1].tick_params(axis='x', labelsize=12)
axes[1].tick_params(axis='y', labelsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Viz 8.1: Top 5 Coldest States by Average Temperature
# ### Viz 8.2: Top 5 Coldest States by Average Temperature

# %%
# Calculate average temperature per state
avg_temp_state = (Weather_Data.groupby('State', as_index=False)['Temperature'].mean())

# Top 5 hottest states
top_5_hot = avg_temp_state.sort_values(by='Temperature', ascending=False).head(5)

# Top 5 coldest states
top_5_cold = avg_temp_state.sort_values(by='Temperature', ascending=True).head(5)

# Create subplots
fig, axes = plt.subplots(2, 1, figsize=(10, 15))

# ____Hot states plot___
ax1 = sns.barplot(
    data=top_5_hot,
    x='State',
    y='Temperature',
    color='orange',
    ax=axes[0], 
    width=0.5
)
axes[0].set_title('Top 5 Hottest States by Average Temperature', fontsize=16)
axes[0].set_xlabel('State', fontsize=14)
axes[0].set_ylabel('Average Temperature (°C)', fontsize=14)
axes[0].bar_label(ax1.containers[0], fmt='%.1f°C', fontsize=12)

axes[0].tick_params(axis='x', labelsize=12)
axes[0].tick_params(axis='y', labelsize=12)

# ___Cold states plot____
ax2 = sns.barplot(
    data=top_5_cold,
    x='State',
    y='Temperature',
    color='cyan',
    ax=axes[1],
    width=0.5
)
axes[1].set_title('Top 5 Coldest States by Average Temperature', fontsize=16)
axes[1].set_xlabel('State', fontsize=14)
axes[1].set_ylabel('Average Temperature (°C)', fontsize=14)
axes[1].bar_label(ax2.containers[0], fmt='%.1f°C', fontsize=12)

axes[1].tick_params(axis='x', labelsize=12)
axes[1].tick_params(axis='y', labelsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 5: Pollution Analysis

# %%
Weather_Data.head()
# Out:
#             UpdatedAt Country CountryCode    State StateCode       City  \
# 0 2025-01-01 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 1 2025-01-02 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 2 2025-01-03 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 3 2025-01-04 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 4 2025-01-05 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
#
#     CityID  Latitude  Longitude WeatherCondition  ...     NO    NO2     O3  \
# 0  1279233   23.0225    72.5714            Clear  ...   5.85  17.70  37.25
# 1  1279233   23.0225    72.5714            Clear  ...  14.94  19.87  33.26
# 2  1279233   23.0225    72.5714            Clear  ...   1.54   7.44  20.31
# 3  1279233   23.0225    72.5714            Clear  ...  14.10  32.39  19.23
# 4  1279233   23.0225    72.5714            Clear  ...   6.23  44.30  25.05
#
#      SO2   PM25    PM10    NH3           CreatedAt       Source        Date
# 0   9.68  77.40  111.46   3.83 2025-01-01 12:00:00  OpenWeather  2025-01-01
# 1  28.91  39.20   56.06  14.72 2025-01-02 12:00:00  OpenWeather  2025-01-02
# 2  15.33  96.25  115.50   3.13 2025-01-03 12:00:00  OpenWeather  2025-01-03
# 3  15.71  37.80   54.05   8.77 2025-01-04 12:00:00  OpenWeather  2025-01-04
# 4   4.77  62.22   89.60   6.80 2025-01-05 12:00:00  OpenWeather  2025-01-05
#
# [5 rows x 37 columns]

# %%
# Map AQI values to categories using range-based mapping
def aqi_category(aqi):
    if pd.isna(aqi):
        return None
    elif aqi <= 50:
        return 'Good'
    elif aqi <= 100:
        return 'Satisfactory'
    elif aqi <= 200:
        return 'Moderate'
    elif aqi <= 300:
        return 'Poor'
    elif aqi <= 400:
        return 'Very Poor'
    else:
        return 'Severe'

Weather_Data['AQI_Category'] = Weather_Data['AQI'].map(aqi_category)

# %%
Weather_Data[['AQI','AQI_Category']]
# Out:
#        AQI  AQI_Category
# 0      172      Moderate
# 1       80  Satisfactory
# 2      175      Moderate
# 3       90  Satisfactory
# 4      122      Moderate
# ...    ...           ...
# 11315   32          Good
# 11316   73  Satisfactory
# 11317   54  Satisfactory
# 11318   74  Satisfactory
# 11319   60  Satisfactory
#
# [11320 rows x 2 columns]

# %% [markdown]
# ### Viz 1: Percentage Distribution of AQI Categories

# %%
aqi_order = ['Good', 'Satisfactory', 'Moderate', 'Poor', 'Very Poor', 'Severe']

aqi_dist = (
    Weather_Data['AQI_Category']
    .value_counts(normalize=True)
    .reindex(aqi_order) * 100
)

plt.figure(figsize=(8,5))
sns.barplot(
    x=aqi_dist.index,
    y=aqi_dist.values,
    palette='viridis'
)

plt.title('Percentage Distribution of AQI Categories')
plt.xlabel('AQI Category')
plt.ylabel('Percentage of Records (%)')
plt.show()
# Out:
# C:\Users\kundu\AppData\Local\Temp\ipykernel_6376\2653360008.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### Viz 2: Top polluted cities by PM2.5
#
# 1. Here, we group the data by 'City Name' and calculate the mean PM2.5 for each city.
#
# 2. We then sort the cities by their average PM2.5 in descending order and select the top 10.
#
# 3. Finally, we print the top 10 cities with the highest average PM2.5 levels.

# %%
# axis_index=False ensures that 'City Name' remains a column after grouping.
# acscending=False sorts the values from highest to lowest.
top_pm25 = (
    Weather_Data.groupby('City', as_index=False)['PM25']
    .mean()
    .sort_values(by='PM25', ascending=False)
    .head(10)
)

print("Top 10 cities by average PM2.5:")
print(top_pm25)
# Out:
# Top 10 cities by average PM2.5:
#          City       PM25
# 4       Delhi  91.218852
# 8      Kanpur  89.674258
# 11    Lucknow  83.586201
# 18   Varanasi  80.676784
# 7      Jaipur  79.060565
# 15      Patna  76.670194
# 10    Kolkata  74.911148
# 2      Bhopal  64.960194
# 0   Ahmedabad  62.804311
# 14     Nagpur  62.075265

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='PM25', y='City', data=top_pm25, palette='Reds_r')
plt.title("Top 10 Most Polluted Cities (PM2.5 Concentration)")
plt.xlabel("PM2.5 (µg/m³)")
plt.ylabel("City Name")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kundu\AppData\Local\Temp\ipykernel_6376\2004844121.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PM25', y='City', data=top_pm25, palette='Reds_r')

# %% [markdown]
# ### Viz 3: Correlation heatmap of pollutants

# %%
# Correlation heatmap of pollutants
pollutants = ['CO','NO','NO2','O3','SO2','PM25','PM10','NH3', 'AQI']

# here figsize sets the size of the figure
# annot=True adds the correlation values on the heatmap
# cmap='coolwarm' sets the color scheme of the heatmap
plt.figure(figsize=(10,6))
sns.heatmap(Weather_Data[pollutants].corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Pollutant Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Viz 4: Top 5 cities that produce most PM2.5 & PM10 particulate matter

# %%
# Find out top 5 cities that produce most PM2.5 & PM10 particulate matter
top_5_pm25_cities = Weather_Data.groupby('City')['PM25'].mean().sort_values(ascending=False).head(5)
top_5_pm10_cities = Weather_Data.groupby('City')['PM10'].mean().sort_values(ascending=False).head(5)

# Show them by using plot
fig, axes = plt.subplots(2, 1, figsize=(10, 15))
top_5_pm25_cities.plot(kind='bar', color='purple', ax=axes[0])
axes[0].set_title("Top 5 Cities by Average PM2.5")
axes[0].set_xlabel("City")
axes[0].set_ylabel("Average PM2.5 (µg/m³)")

top_5_pm10_cities.plot(kind='bar', color='brown', ax=axes[1])
axes[1].set_title("Top 5 Cities by Average PM10")
axes[1].set_xlabel("City")
axes[1].set_ylabel("Average PM10 (µg/m³)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 6: Weather vs Pollution Relationships

# %% [markdown]
# ### Viz 1: Temperature vs PM2.5

# %%
# Scatter plot: Temperature vs PM2.5
sns.jointplot(x='Temperature', y='PM25', data=Weather_Data, kind='scatter', height=7, color='g')

# Adjust title & position
plt.suptitle("Temperature vs PM2.5", y=1.02)
plt.show()

# %% [markdown]
# ### Viz 2: Effect of Wind Speed on Pollution (Dispersion Effect)
# ### Insight: Higher wind speed helps reduce pollution levels.

# %%
# Wind speed vs PM2.5
sns.jointplot(x='WindSpeed', y='PM25', data=Weather_Data, kind='scatter', height=7, color='cyan')

# Adjust the title position
plt.suptitle("Wind Speed vs PM2.5", y=1.02)
plt.show()

# %% [markdown]
# ### Viz 3: Humidity vs PM2.5
# - Shows how moisture affects pollution accumulation
# - Very relevant for haze/mist conditions

# %%
plt.figure(figsize=(8,6))
sns.jointplot(
    data=Weather_Data,
    kind='hex',
    x='Humidity',
    y='PM25',
    height=7,
    color='LightSeaGreen'
)

plt.suptitle('Effect of Humidity on PM2.5 Levels', y=1.02)
plt.xlabel('Humidity (%)')
plt.ylabel('PM2.5 (µg/m³)')
plt.show()

# %% [markdown]
# ### Viz 4: Overall Relationship between Temperature and PM2.5

# %%
sns.regplot(
    data=Weather_Data,
    x='PM25',
    y='Temperature',
    scatter_kws={'alpha':0.5},
    line_kws={'color':'red'}
)
plt.title('Overall Relationship between Temperature and PM2.5')
plt.xlabel('PM2.5 (µg/m³)')
plt.ylabel('Temperature (°C)')
plt.show()

# %% [markdown]
# ### Viz 5: PM2.5 vs Temperature by City

# %%
g = sns.FacetGrid(
    Weather_Data,
    col='City',
    col_wrap=4,
    height=3,
)

g.map(sns.scatterplot, 'PM25', 'Temperature')
g.fig.suptitle('PM2.5 vs Temperature by City', y=1.05)
plt.show()

# %% [markdown]
# ### Viz 6: PM10 vs Temperature by City

# %%
g = sns.FacetGrid(
    Weather_Data,
    col='City',
    col_wrap=4,
    height=3
)

g.map(sns.scatterplot, 'PM10', 'Temperature')
g.fig.suptitle('PM10 vs Temperature by City', y=1.05)
plt.show()

# %% [markdown]
# ### Viz 7: Visibility vs PM2.5 (Smog Identification)
# ### Insight: High PM2.5 severely reduces visibility → smog conditions.

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=Weather_Data,
    x='PM25',
    y='Visibility', 
    alpha=0.5, 
    color="goldenrod"
)
plt.title('Impact of PM2.5 on Visibility')
plt.xlabel('PM2.5 (µg/m³)')
plt.ylabel('Visibility')
plt.show()

# %%
Weather_Data.head()
# Out:
#             UpdatedAt Country CountryCode    State StateCode       City  \
# 0 2025-01-01 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 1 2025-01-02 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 2 2025-01-03 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 3 2025-01-04 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 4 2025-01-05 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
#
#     CityID  Latitude  Longitude WeatherCondition  ...    NO2     O3    SO2  \
# 0  1279233   23.0225    72.5714            Clear  ...  17.70  37.25   9.68
# 1  1279233   23.0225    72.5714            Clear  ...  19.87  33.26  28.91
# 2  1279233   23.0225    72.5714            Clear  ...   7.44  20.31  15.33
# 3  1279233   23.0225    72.5714            Clear  ...  32.39  19.23  15.71
# 4  1279233   23.0225    72.5714            Clear  ...  44.30  25.05   4.77
#
#     PM25    PM10    NH3           CreatedAt       Source        Date  \
# 0  77.40  111.46   3.83 2025-01-01 12:00:00  OpenWeather  2025-01-01
# 1  39.20   56.06  14.72 2025-01-02 12:00:00  OpenWeather  2025-01-02
# 2  96.25  115.50   3.13 2025-01-03 12:00:00  OpenWeather  2025-01-03
# 3  37.80   54.05   8.77 2025-01-04 12:00:00  OpenWeather  2025-01-04
# 4  62.22   89.60   6.80 2025-01-05 12:00:00  OpenWeather  2025-01-05
#
#    AQI_Category
# 0      Moderate
# 1  Satisfactory
# 2      Moderate
# 3  Satisfactory
# 4      Moderate
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Step 5: AQI vs. Pollution analysis

# %% [markdown]
# ### Viz 1: % Of Very Poor & Severe proportion
# ### Insight : “Which cities most frequently experience bad air quality?”

# %%
# # See how many times Kolkata appears in the dataset
# kolkata_count = Weather_Data[Weather_Data['City'] == 'Kolkata'].shape[0]
# print(f"Kolkata appears {kolkata_count} times in the dataset.")

# # Same for darjeeling
# darjeeling_count = Weather_Data[Weather_Data['City'] == 'Darjeeling'].shape[0]
# print(f"Darjeeling appears {darjeeling_count} times in the dataset.")

# %%
MIN_DAYS = 200

city_counts = Weather_Data["City"].value_counts()
valid_cities = city_counts[city_counts >= MIN_DAYS].index

df_valid = Weather_Data[Weather_Data["City"].isin(valid_cities)]

# %%
Weather_Data['AQI_Category'].value_counts()
# Out:
# AQI_Category
# Moderate        4607
# Satisfactory    4158
# Good            1527
# Poor             836
# Very Poor        192
# Name: count, dtype: int64

# %%
# Proportion of Poor / Severe AQI Days means
poor_severe = ["Very Poor", "Severe"]

city_ratio = (
    df_valid["AQI_Category"]
    .isin(poor_severe)
    .groupby(df_valid["City"])
    .mean()
    .sort_values(ascending=False)
    .head(5)
)

# %%
plt.figure(figsize=(10,6))
city_ratio.sort_values().plot(kind="barh", color='salmon')
plt.xlabel("Proportion of Very Poor/Severe AQI Records", y=1.2)
plt.title("Proportion of Very Poor & Severe AQI Records by City (Cities with ≥ 200 AQI records)")
plt.tight_layout()
plt.show()

# %%
# Find out Top 10 cities have highest AQI
city_aqi = (
    Weather_Data.groupby('City', as_index=False)['AQI']
    .mean()
    .sort_values(by='AQI', ascending=False)
    .head(10)
)

plt.figure(figsize=(10,6))
sns.barplot(x='AQI', y='City', data=city_aqi, palette='RdYlGn')
plt.title("Top 10 Cities by Average AQI", fontsize=14, y=1.02)
plt.xlabel("Average AQI")
plt.ylabel("City Name")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kundu\AppData\Local\Temp\ipykernel_6376\1291824755.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='AQI', y='City', data=city_aqi, palette='RdYlGn')

# %% [markdown]
# ### Viz 2: Relationship between PM2.5 and AQI Category

# %%
plt.figure(figsize=(8,6))
sns.barplot(
    data=Weather_Data,
    x= 'AQI_Category',
    y= 'PM25',
    hue='AQI_Category',
    legend=True
)

plt.title('Relationship between PM2.5 and AQI Category')
plt.xlabel('AQI Category')
plt.ylabel('PM2.5 (µg/m³)')
plt.show()

# %%
# Final AQI vs Temperature
plt.figure(figsize=(15,6))
sns.jointplot(
    data=Weather_Data,
    x='AQI',
    y='Temperature',
    hue='AQI_Category',
    palette='Set2'
)

plt.title('Relationship between Temperature and AQI', y=1.25)
plt.xlabel('AQI')
plt.ylabel('Temperature (°C)')
plt.show()

# %%
# AQI Distribution by City
plt.figure(figsize=(12,8))
sns.boxplot(
    data=Weather_Data,
    x='AQI',
    y='City',
    palette='Set3'
)

plt.title('AQI Distribution by City')
plt.xlabel('AQI')
plt.ylabel('City')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\kundu\AppData\Local\Temp\ipykernel_6376\466973704.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# ## Extract & place the Updated Data to dedicated path

# %%
from pathlib import Path

# 1. Define distinct paths.
output_dir = Path("../Datasets")
file_path = "../Datasets/Forecasting_Data.csv"
    
# 2. Ensure the dedicated output folder exists
output_dir.mkdir(parents=True, exist_ok=True)

# 3. Save the cleaned copy to your dedicated path
Weather_Data.to_csv(file_path, index=False)

print(f"Cleaned data saved safely at: {file_path}")
# Out:
# Cleaned data saved safely at: ../Datasets/Forecasting_Data.csv

# %%
# Check latest Date
Weather_Data['Date'].max()
# Out:
# datetime.date(2026, 7, 19)
