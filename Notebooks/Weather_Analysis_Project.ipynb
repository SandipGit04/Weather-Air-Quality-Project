# %% [markdown]
# ## EDA : On Weather & Pollution Data:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the dataset from the specified path
Weather = pd.read_csv('../Datasets/Weather_Pollution_Data.csv')
Weather.head()
# Out:
#   Country CountryCode        State StateCode       City   CityID  Latitude  \
# 0   India          IN  West Bengal        WB    Kolkata  1275004   22.5726
# 1   India          IN        Delhi        DL      Delhi  1273294   28.6139
# 2   India          IN  Maharashtra        MH     Mumbai  1275339   19.0760
# 3   India          IN    Telangana        TG  Hyderabad  1269843   17.3850
# 4   India          IN    Karnataka        KA  Bengaluru  1277333   12.9716
#
#    Longitude WeatherCondition WeatherDescription  ...       CO     NO    NO2  \
# 0    88.3639           Clouds         few clouds  ...  1391.43  14.30  25.30
# 1    77.2090           Clouds         few clouds  ...  1341.75  17.03  49.99
# 2    72.8777             Rain         light rain  ...   742.07  15.19  21.25
# 3    78.4867             Rain         light rain  ...  1323.43   2.60  52.11
# 4    77.5946             Rain         light rain  ...   237.51  11.15  45.73
#
#       O3    SO2   PM25   PM10    NH3              CreatedAt  \
# 0  45.29  24.58  54.54  72.54   5.29  1/6/2025, 12:00:00 pm
# 1  49.60   5.37  37.96  55.42   6.66  1/6/2025, 12:00:00 pm
# 2  26.79  20.37  36.30  48.64   5.93  1/6/2025, 12:00:00 pm
# 3  26.74  27.55  52.43  68.68   1.00  1/6/2025, 12:00:00 pm
# 4  28.44   8.40  47.40  56.88  10.61  1/6/2025, 12:00:00 pm
#
#                UpdatedAt
# 0  1/6/2025, 12:00:00 pm
# 1  1/6/2025, 12:00:00 pm
# 2  1/6/2025, 12:00:00 pm
# 3  1/6/2025, 12:00:00 pm
# 4  1/6/2025, 12:00:00 pm
#
# [5 rows x 35 columns]

# %%
Weather_Data = Weather.copy()

# %%
Weather_Data
# Out:
#      Country CountryCode           State StateCode       City   CityID  \
# 0      India          IN     West Bengal        WB    Kolkata  1275004
# 1      India          IN           Delhi        DL      Delhi  1273294
# 2      India          IN     Maharashtra        MH     Mumbai  1275339
# 3      India          IN       Telangana        TG  Hyderabad  1269843
# 4      India          IN       Karnataka        KA  Bengaluru  1277333
# ...      ...         ...             ...       ...        ...      ...
# 7595   India          IN         Gujarat        GJ      Surat  1255364
# 7596   India          IN  Madhya Pradesh        MP     Bhopal  1275817
# 7597   India          IN          Kerala        KL      Kochi  1267990
# 7598   India          IN             Goa        GA        Goa  1256523
# 7599   India          IN       Karnataka        KA     Mysuru  1262321
#
#       Latitude  Longitude WeatherCondition WeatherDescription  ...       CO  \
# 0      22.5726    88.3639           Clouds         few clouds  ...  1391.43
# 1      28.6139    77.2090           Clouds         few clouds  ...  1341.75
# 2      19.0760    72.8777             Rain         light rain  ...   742.07
# 3      17.3850    78.4867             Rain         light rain  ...  1323.43
# 4      12.9716    77.5946             Rain         light rain  ...   237.51
# ...        ...        ...              ...                ...  ...      ...
# 7595   21.1702    72.8311             Rain         light rain  ...   831.37
# 7596   23.2599    77.4126           Clouds         few clouds  ...   823.55
# 7597    9.9312    76.2673             Rain         light rain  ...   530.54
# 7598   15.2993    74.1240             Rain         light rain  ...   762.75
# 7599   12.2958    76.6394     Thunderstorm       thunderstorm  ...  1135.57
#
#          NO    NO2     O3    SO2   PM25   PM10    NH3               CreatedAt  \
# 0     14.30  25.30  45.29  24.58  54.54  72.54   5.29   1/6/2025, 12:00:00 pm
# 1     17.03  49.99  49.60   5.37  37.96  55.42   6.66   1/6/2025, 12:00:00 pm
# 2     15.19  21.25  26.79  20.37  36.30  48.64   5.93   1/6/2025, 12:00:00 pm
# 3      2.60  52.11  26.74  27.55  52.43  68.68   1.00   1/6/2025, 12:00:00 pm
# 4     11.15  45.73  28.44   8.40  47.40  56.88  10.61   1/6/2025, 12:00:00 pm
# ...     ...    ...    ...    ...    ...    ...    ...                     ...
# 7595  11.00  49.88  46.57   4.62  64.20  86.67   1.09  15/6/2026, 12:00:00 pm
# 7596   8.96  22.94  14.73  20.32  56.99  89.47  11.80  15/6/2026, 12:00:00 pm
# 7597   2.21  32.01  43.16  11.41  25.08  34.11   4.67  15/6/2026, 12:00:00 pm
# 7598   7.88   5.51  65.16  15.95  33.58  43.65  11.74  15/6/2026, 12:00:00 pm
# 7599  17.03   5.26  12.53  23.46  16.74  25.11   2.13  15/6/2026, 12:00:00 pm
#
#                    UpdatedAt
# 0      1/6/2025, 12:00:00 pm
# 1      1/6/2025, 12:00:00 pm
# 2      1/6/2025, 12:00:00 pm
# 3      1/6/2025, 12:00:00 pm
# 4      1/6/2025, 12:00:00 pm
# ...                      ...
# 7595  15/6/2026, 12:00:00 pm
# 7596  15/6/2026, 12:00:00 pm
# 7597  15/6/2026, 12:00:00 pm
# 7598  15/6/2026, 12:00:00 pm
# 7599  15/6/2026, 12:00:00 pm
#
# [7600 rows x 35 columns]

# %%
Weather_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7600 entries, 0 to 7599
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             7600 non-null   object
#  1   CountryCode         7600 non-null   object
#  2   State               7600 non-null   object
#  3   StateCode           7600 non-null   object
#  4   City                7600 non-null   object
#  5   CityID              7600 non-null   int64
#  6   Latitude            7600 non-null   float64
#  7   Longitude           7600 non-null   float64
#  8   WeatherCondition    7600 non-null   object
#  9   WeatherDescription  7600 non-null   object
#  10  WeatherCode         7600 non-null   int64
#  11  Temperature         7600 non-null   float64
#  12  FeelsLike           7600 non-null   float64
#  13  TempMin             7600 non-null   int64
#  14  TempMax             7600 non-null   int64
#  15  Pressure            7600 non-null   int64
#  16  Humidity            7600 non-null   int64
#  17  SeaLevel            7600 non-null   int64
#  18  GroundLevel         7600 non-null   int64
#  19  WindSpeed           7600 non-null   float64
#  20  WindDirection       7600 non-null   int64
#  21  WindGust            7600 non-null   float64
#  22  CloudCoverage       7600 non-null   int64
#  23  Visibility          7600 non-null   int64
#  24  AQI                 7600 non-null   int64
#  25  CO                  7600 non-null   float64
#  26  NO                  7600 non-null   float64
#  27  NO2                 7600 non-null   float64
#  28  O3                  7600 non-null   float64
#  29  SO2                 7600 non-null   float64
#  30  PM25                7600 non-null   float64
#  31  PM10                7600 non-null   float64
#  32  NH3                 7600 non-null   float64
#  33  CreatedAt           7600 non-null   object
#  34  UpdatedAt           7600 non-null   object
# dtypes: float64(14), int64(12), object(9)
# memory usage: 2.0+ MB

# %%
Weather_Data.describe()
# Out:
#              CityID     Latitude    Longitude  WeatherCode  Temperature  \
# count  7.600000e+03  7600.000000  7600.000000  7600.000000  7600.000000
# mean   1.266262e+06    20.357720    78.299435   682.549605    27.841437
# std    8.022117e+03     5.440234     4.211750   192.548151     6.584679
# min    1.252783e+06     9.931200    72.571400   211.000000     6.910000
# 25%    1.259872e+06    16.863575    75.371475   500.000000    24.040000
# 50%    1.266362e+06    21.158000    77.503600   800.000000    28.295000
# 75%    1.273722e+06    25.386725    80.485475   800.000000    32.212500
# max    1.279233e+06    28.613900    88.363900   801.000000    44.550000
#
#          FeelsLike      TempMin      TempMax     Pressure     Humidity  ...  \
# count  7600.000000  7600.000000  7600.000000  7600.000000  7600.000000  ...
# mean     27.820221    21.489605    34.001447  1010.031842    61.572237  ...
# std       6.690285     6.097998     5.373079     8.689314    19.426270  ...
# min       5.940000     6.000000    21.000000   995.000000    15.000000  ...
# 25%      23.840000    18.000000    30.000000  1003.000000    46.000000  ...
# 50%      28.160000    23.000000    34.000000  1010.000000    63.000000  ...
# 75%      32.260000    27.000000    38.000000  1018.000000    77.000000  ...
# max      45.420000    30.000000    45.000000  1025.000000   100.000000  ...
#
#          Visibility          AQI           CO           NO          NO2  \
# count   7600.000000  7600.000000  7600.000000  7600.000000  7600.000000
# mean    6643.638816   111.558684   859.246747    10.027809    32.697207
# std     2109.493184    61.454196   372.403528     5.794989    16.043552
# min      505.000000    15.000000   200.110000     0.000000     5.000000
# 25%     5131.750000    67.000000   543.200000     5.017500    18.635000
# 50%     6753.500000    99.000000   862.755000    10.020000    32.830000
# 75%     8365.000000   140.000000  1178.742500    15.040000    46.680000
# max    10000.000000   400.000000  1499.990000    20.000000    59.990000
#
#                 O3          SO2         PM25         PM10          NH3
# count  7600.000000  7600.000000  7600.000000  7600.000000  7600.000000
# mean     45.141942    16.130618    55.731659    78.051617     7.951322
# std      20.127652     8.028715    31.622628    44.831824     4.022727
# min      10.000000     2.000000     6.150000     8.320000     1.000000
# 25%      27.667500     9.230000    33.280000    45.900000     4.480000
# 50%      45.160000    16.080000    49.200000    68.755000     7.845000
# 75%      62.402500    23.062500    70.400000    98.800000    11.430000
# max      79.990000    30.000000   227.430000   339.890000    15.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# ### Step 2: Data Cleaning

# %%
# Convert CreatedAt & UpdatedAt strings to datetime
Weather_Data['CreatedAt'] = pd.to_datetime(Weather_Data['CreatedAt'], format='%d/%m/%Y, %I:%M:%S %p')
Weather_Data['UpdatedAt'] = pd.to_datetime(Weather_Data['UpdatedAt'], format='%d/%m/%Y, %I:%M:%S %p')
Weather_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7600 entries, 0 to 7599
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             7600 non-null   object
#  1   CountryCode         7600 non-null   object
#  2   State               7600 non-null   object
#  3   StateCode           7600 non-null   object
#  4   City                7600 non-null   object
#  5   CityID              7600 non-null   int64
#  6   Latitude            7600 non-null   float64
#  7   Longitude           7600 non-null   float64
#  8   WeatherCondition    7600 non-null   object
#  9   WeatherDescription  7600 non-null   object
#  10  WeatherCode         7600 non-null   int64
#  11  Temperature         7600 non-null   float64
#  12  FeelsLike           7600 non-null   float64
#  13  TempMin             7600 non-null   int64
#  14  TempMax             7600 non-null   int64
#  15  Pressure            7600 non-null   int64
#  16  Humidity            7600 non-null   int64
#  17  SeaLevel            7600 non-null   int64
#  18  GroundLevel         7600 non-null   int64
#  19  WindSpeed           7600 non-null   float64
#  20  WindDirection       7600 non-null   int64
#  21  WindGust            7600 non-null   float64
#  22  CloudCoverage       7600 non-null   int64
#  23  Visibility          7600 non-null   int64
#  24  AQI                 7600 non-null   int64
#  25  CO                  7600 non-null   float64
#  26  NO                  7600 non-null   float64
#  27  NO2                 7600 non-null   float64
#  28  O3                  7600 non-null   float64
#  29  SO2                 7600 non-null   float64
#  30  PM25                7600 non-null   float64
#  31  PM10                7600 non-null   float64
#  32  NH3                 7600 non-null   float64
#  33  CreatedAt           7600 non-null   datetime64[ns]
#  34  UpdatedAt           7600 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(14), int64(12), object(7)
# memory usage: 2.0+ MB

# %%
Weather_Data
# Out:
#      Country CountryCode           State StateCode       City   CityID  \
# 0      India          IN     West Bengal        WB    Kolkata  1275004
# 1      India          IN           Delhi        DL      Delhi  1273294
# 2      India          IN     Maharashtra        MH     Mumbai  1275339
# 3      India          IN       Telangana        TG  Hyderabad  1269843
# 4      India          IN       Karnataka        KA  Bengaluru  1277333
# ...      ...         ...             ...       ...        ...      ...
# 7595   India          IN         Gujarat        GJ      Surat  1255364
# 7596   India          IN  Madhya Pradesh        MP     Bhopal  1275817
# 7597   India          IN          Kerala        KL      Kochi  1267990
# 7598   India          IN             Goa        GA        Goa  1256523
# 7599   India          IN       Karnataka        KA     Mysuru  1262321
#
#       Latitude  Longitude WeatherCondition WeatherDescription  ...       CO  \
# 0      22.5726    88.3639           Clouds         few clouds  ...  1391.43
# 1      28.6139    77.2090           Clouds         few clouds  ...  1341.75
# 2      19.0760    72.8777             Rain         light rain  ...   742.07
# 3      17.3850    78.4867             Rain         light rain  ...  1323.43
# 4      12.9716    77.5946             Rain         light rain  ...   237.51
# ...        ...        ...              ...                ...  ...      ...
# 7595   21.1702    72.8311             Rain         light rain  ...   831.37
# 7596   23.2599    77.4126           Clouds         few clouds  ...   823.55
# 7597    9.9312    76.2673             Rain         light rain  ...   530.54
# 7598   15.2993    74.1240             Rain         light rain  ...   762.75
# 7599   12.2958    76.6394     Thunderstorm       thunderstorm  ...  1135.57
#
#          NO    NO2     O3    SO2   PM25   PM10    NH3           CreatedAt  \
# 0     14.30  25.30  45.29  24.58  54.54  72.54   5.29 2025-06-01 12:00:00
# 1     17.03  49.99  49.60   5.37  37.96  55.42   6.66 2025-06-01 12:00:00
# 2     15.19  21.25  26.79  20.37  36.30  48.64   5.93 2025-06-01 12:00:00
# 3      2.60  52.11  26.74  27.55  52.43  68.68   1.00 2025-06-01 12:00:00
# 4     11.15  45.73  28.44   8.40  47.40  56.88  10.61 2025-06-01 12:00:00
# ...     ...    ...    ...    ...    ...    ...    ...                 ...
# 7595  11.00  49.88  46.57   4.62  64.20  86.67   1.09 2026-06-15 12:00:00
# 7596   8.96  22.94  14.73  20.32  56.99  89.47  11.80 2026-06-15 12:00:00
# 7597   2.21  32.01  43.16  11.41  25.08  34.11   4.67 2026-06-15 12:00:00
# 7598   7.88   5.51  65.16  15.95  33.58  43.65  11.74 2026-06-15 12:00:00
# 7599  17.03   5.26  12.53  23.46  16.74  25.11   2.13 2026-06-15 12:00:00
#
#                UpdatedAt
# 0    2025-06-01 12:00:00
# 1    2025-06-01 12:00:00
# 2    2025-06-01 12:00:00
# 3    2025-06-01 12:00:00
# 4    2025-06-01 12:00:00
# ...                  ...
# 7595 2026-06-15 12:00:00
# 7596 2026-06-15 12:00:00
# 7597 2026-06-15 12:00:00
# 7598 2026-06-15 12:00:00
# 7599 2026-06-15 12:00:00
#
# [7600 rows x 35 columns]

# %%
# Extract Only Date from 'Record Created At' for further analysis
Weather_Data['Date'] = Weather_Data['UpdatedAt'].dt.date
Weather_Data
# Out:
#      Country CountryCode           State StateCode       City   CityID  \
# 0      India          IN     West Bengal        WB    Kolkata  1275004
# 1      India          IN           Delhi        DL      Delhi  1273294
# 2      India          IN     Maharashtra        MH     Mumbai  1275339
# 3      India          IN       Telangana        TG  Hyderabad  1269843
# 4      India          IN       Karnataka        KA  Bengaluru  1277333
# ...      ...         ...             ...       ...        ...      ...
# 7595   India          IN         Gujarat        GJ      Surat  1255364
# 7596   India          IN  Madhya Pradesh        MP     Bhopal  1275817
# 7597   India          IN          Kerala        KL      Kochi  1267990
# 7598   India          IN             Goa        GA        Goa  1256523
# 7599   India          IN       Karnataka        KA     Mysuru  1262321
#
#       Latitude  Longitude WeatherCondition WeatherDescription  ...     NO  \
# 0      22.5726    88.3639           Clouds         few clouds  ...  14.30
# 1      28.6139    77.2090           Clouds         few clouds  ...  17.03
# 2      19.0760    72.8777             Rain         light rain  ...  15.19
# 3      17.3850    78.4867             Rain         light rain  ...   2.60
# 4      12.9716    77.5946             Rain         light rain  ...  11.15
# ...        ...        ...              ...                ...  ...    ...
# 7595   21.1702    72.8311             Rain         light rain  ...  11.00
# 7596   23.2599    77.4126           Clouds         few clouds  ...   8.96
# 7597    9.9312    76.2673             Rain         light rain  ...   2.21
# 7598   15.2993    74.1240             Rain         light rain  ...   7.88
# 7599   12.2958    76.6394     Thunderstorm       thunderstorm  ...  17.03
#
#         NO2     O3    SO2   PM25   PM10    NH3           CreatedAt  \
# 0     25.30  45.29  24.58  54.54  72.54   5.29 2025-06-01 12:00:00
# 1     49.99  49.60   5.37  37.96  55.42   6.66 2025-06-01 12:00:00
# 2     21.25  26.79  20.37  36.30  48.64   5.93 2025-06-01 12:00:00
# 3     52.11  26.74  27.55  52.43  68.68   1.00 2025-06-01 12:00:00
# 4     45.73  28.44   8.40  47.40  56.88  10.61 2025-06-01 12:00:00
# ...     ...    ...    ...    ...    ...    ...                 ...
# 7595  49.88  46.57   4.62  64.20  86.67   1.09 2026-06-15 12:00:00
# 7596  22.94  14.73  20.32  56.99  89.47  11.80 2026-06-15 12:00:00
# 7597  32.01  43.16  11.41  25.08  34.11   4.67 2026-06-15 12:00:00
# 7598   5.51  65.16  15.95  33.58  43.65  11.74 2026-06-15 12:00:00
# 7599   5.26  12.53  23.46  16.74  25.11   2.13 2026-06-15 12:00:00
#
#                UpdatedAt        Date
# 0    2025-06-01 12:00:00  2025-06-01
# 1    2025-06-01 12:00:00  2025-06-01
# 2    2025-06-01 12:00:00  2025-06-01
# 3    2025-06-01 12:00:00  2025-06-01
# 4    2025-06-01 12:00:00  2025-06-01
# ...                  ...         ...
# 7595 2026-06-15 12:00:00  2026-06-15
# 7596 2026-06-15 12:00:00  2026-06-15
# 7597 2026-06-15 12:00:00  2026-06-15
# 7598 2026-06-15 12:00:00  2026-06-15
# 7599 2026-06-15 12:00:00  2026-06-15
#
# [7600 rows x 36 columns]

# %%
Weather_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7600 entries, 0 to 7599
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             7600 non-null   object
#  1   CountryCode         7600 non-null   object
#  2   State               7600 non-null   object
#  3   StateCode           7600 non-null   object
#  4   City                7600 non-null   object
#  5   CityID              7600 non-null   int64
#  6   Latitude            7600 non-null   float64
#  7   Longitude           7600 non-null   float64
#  8   WeatherCondition    7600 non-null   object
#  9   WeatherDescription  7600 non-null   object
#  10  WeatherCode         7600 non-null   int64
#  11  Temperature         7600 non-null   float64
#  12  FeelsLike           7600 non-null   float64
#  13  TempMin             7600 non-null   int64
#  14  TempMax             7600 non-null   int64
#  15  Pressure            7600 non-null   int64
#  16  Humidity            7600 non-null   int64
#  17  SeaLevel            7600 non-null   int64
#  18  GroundLevel         7600 non-null   int64
#  19  WindSpeed           7600 non-null   float64
#  20  WindDirection       7600 non-null   int64
#  21  WindGust            7600 non-null   float64
#  22  CloudCoverage       7600 non-null   int64
#  23  Visibility          7600 non-null   int64
#  24  AQI                 7600 non-null   int64
#  25  CO                  7600 non-null   float64
#  26  NO                  7600 non-null   float64
#  27  NO2                 7600 non-null   float64
#  28  O3                  7600 non-null   float64
#  29  SO2                 7600 non-null   float64
#  30  PM25                7600 non-null   float64
#  31  PM10                7600 non-null   float64
#  32  NH3                 7600 non-null   float64
#  33  CreatedAt           7600 non-null   datetime64[ns]
#  34  UpdatedAt           7600 non-null   datetime64[ns]
#  35  Date                7600 non-null   object
# dtypes: datetime64[ns](2), float64(14), int64(12), object(8)
# memory usage: 2.1+ MB

# %%
Weather_Data.describe()
# Out:
#              CityID     Latitude    Longitude  WeatherCode  Temperature  \
# count  7.600000e+03  7600.000000  7600.000000  7600.000000  7600.000000
# mean   1.266262e+06    20.357720    78.299435   682.549605    27.841437
# min    1.252783e+06     9.931200    72.571400   211.000000     6.910000
# 25%    1.259872e+06    16.863575    75.371475   500.000000    24.040000
# 50%    1.266362e+06    21.158000    77.503600   800.000000    28.295000
# 75%    1.273722e+06    25.386725    80.485475   800.000000    32.212500
# max    1.279233e+06    28.613900    88.363900   801.000000    44.550000
# std    8.022117e+03     5.440234     4.211750   192.548151     6.584679
#
#          FeelsLike      TempMin      TempMax     Pressure     Humidity  ...  \
# count  7600.000000  7600.000000  7600.000000  7600.000000  7600.000000  ...
# mean     27.820221    21.489605    34.001447  1010.031842    61.572237  ...
# min       5.940000     6.000000    21.000000   995.000000    15.000000  ...
# 25%      23.840000    18.000000    30.000000  1003.000000    46.000000  ...
# 50%      28.160000    23.000000    34.000000  1010.000000    63.000000  ...
# 75%      32.260000    27.000000    38.000000  1018.000000    77.000000  ...
# max      45.420000    30.000000    45.000000  1025.000000   100.000000  ...
# std       6.690285     6.097998     5.373079     8.689314    19.426270  ...
#
#                 CO           NO          NO2           O3          SO2  \
# count  7600.000000  7600.000000  7600.000000  7600.000000  7600.000000
# mean    859.246747    10.027809    32.697207    45.141942    16.130618
# min     200.110000     0.000000     5.000000    10.000000     2.000000
# 25%     543.200000     5.017500    18.635000    27.667500     9.230000
# 50%     862.755000    10.020000    32.830000    45.160000    16.080000
# 75%    1178.742500    15.040000    46.680000    62.402500    23.062500
# max    1499.990000    20.000000    59.990000    79.990000    30.000000
# std     372.403528     5.794989    16.043552    20.127652     8.028715
#
#               PM25         PM10          NH3            CreatedAt  \
# count  7600.000000  7600.000000  7600.000000                 7600
# mean     55.731659    78.051617     7.951322  2025-12-08 00:00:00
# min       6.150000     8.320000     1.000000  2025-06-01 12:00:00
# 25%      33.280000    45.900000     4.480000  2025-09-04 06:00:00
# 50%      49.200000    68.755000     7.845000  2025-12-08 00:00:00
# 75%      70.400000    98.800000    11.430000  2026-03-12 18:00:00
# max     227.430000   339.890000    15.000000  2026-06-15 12:00:00
# std      31.622628    44.831824     4.022727                  NaN
#
#                  UpdatedAt
# count                 7600
# mean   2025-12-08 00:00:00
# min    2025-06-01 12:00:00
# 25%    2025-09-04 06:00:00
# 50%    2025-12-08 00:00:00
# 75%    2026-03-12 18:00:00
# max    2026-06-15 12:00:00
# std                    NaN
#
# [8 rows x 28 columns]

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# UpdatedAt             0
# Date                  0
# dtype: int64

# %% [markdown]
# ### Step 1: First quantify & visualize missingness

# %%
Weather_Data.head()
# Out:
#   Country CountryCode        State StateCode       City   CityID  Latitude  \
# 0   India          IN  West Bengal        WB    Kolkata  1275004   22.5726
# 1   India          IN        Delhi        DL      Delhi  1273294   28.6139
# 2   India          IN  Maharashtra        MH     Mumbai  1275339   19.0760
# 3   India          IN    Telangana        TG  Hyderabad  1269843   17.3850
# 4   India          IN    Karnataka        KA  Bengaluru  1277333   12.9716
#
#    Longitude WeatherCondition WeatherDescription  ...     NO    NO2     O3  \
# 0    88.3639           Clouds         few clouds  ...  14.30  25.30  45.29
# 1    77.2090           Clouds         few clouds  ...  17.03  49.99  49.60
# 2    72.8777             Rain         light rain  ...  15.19  21.25  26.79
# 3    78.4867             Rain         light rain  ...   2.60  52.11  26.74
# 4    77.5946             Rain         light rain  ...  11.15  45.73  28.44
#
#      SO2   PM25   PM10    NH3           CreatedAt           UpdatedAt  \
# 0  24.58  54.54  72.54   5.29 2025-06-01 12:00:00 2025-06-01 12:00:00
# 1   5.37  37.96  55.42   6.66 2025-06-01 12:00:00 2025-06-01 12:00:00
# 2  20.37  36.30  48.64   5.93 2025-06-01 12:00:00 2025-06-01 12:00:00
# 3  27.55  52.43  68.68   1.00 2025-06-01 12:00:00 2025-06-01 12:00:00
# 4   8.40  47.40  56.88  10.61 2025-06-01 12:00:00 2025-06-01 12:00:00
#
#          Date
# 0  2025-06-01
# 1  2025-06-01
# 2  2025-06-01
# 3  2025-06-01
# 4  2025-06-01
#
# [5 rows x 36 columns]

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# UpdatedAt             0
# Date                  0
# dtype: int64

# %% [markdown]
# ### Step 1: Remove duplicates if any

# %%
# Count duplicates if any
duplicate_count = Weather_Data.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
# Remove duplicates data in the dataset
Weather_Data = Weather_Data.drop_duplicates()

# %%
# Count duplicates if any
duplicate_count = Weather_Data.duplicated().sum()
print(f"After removing duplicates the number of duplicate rows is: {duplicate_count}")
# Out:
# After removing duplicates the number of duplicate rows is: 0

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# UpdatedAt             0
# Date                  0
# dtype: int64

# %% [markdown]
# ### Step 2: Fix Wind variables (time-aware)
# - Data Cleaning - Handling Missing Values Of 'Wind Speed (m/s)' Column Using Interpolation
# - Interpolation means estimating missing values that fall within the range of known values.
# - Then we will use time-based interpolation since our data is time-series data.

# %%
# Sort the data by City Name and Record Created At
Weather_Data = Weather_Data.sort_values(['City','UpdatedAt','Date'])
Weather_Data
# Out:
#      Country CountryCode           State StateCode           City   CityID  \
# 7      India          IN         Gujarat        GJ      Ahmedabad  1279233
# 27     India          IN         Gujarat        GJ      Ahmedabad  1279233
# 47     India          IN         Gujarat        GJ      Ahmedabad  1279233
# 67     India          IN         Gujarat        GJ      Ahmedabad  1279233
# 87     India          IN         Gujarat        GJ      Ahmedabad  1279233
# ...      ...         ...             ...       ...            ...      ...
# 7513   India          IN  Andhra Pradesh        AP  Visakhapatnam  1252783
# 7533   India          IN  Andhra Pradesh        AP  Visakhapatnam  1252783
# 7553   India          IN  Andhra Pradesh        AP  Visakhapatnam  1252783
# 7573   India          IN  Andhra Pradesh        AP  Visakhapatnam  1252783
# 7593   India          IN  Andhra Pradesh        AP  Visakhapatnam  1252783
#
#       Latitude  Longitude WeatherCondition WeatherDescription  ...     NO  \
# 7      23.0225    72.5714             Rain         light rain  ...   4.43
# 27     23.0225    72.5714             Rain         light rain  ...   8.74
# 47     23.0225    72.5714     Thunderstorm       thunderstorm  ...  14.69
# 67     23.0225    72.5714            Clear          clear sky  ...  16.81
# 87     23.0225    72.5714           Clouds         few clouds  ...  15.13
# ...        ...        ...              ...                ...  ...    ...
# 7513   17.6868    83.2185     Thunderstorm       thunderstorm  ...   5.72
# 7533   17.6868    83.2185             Rain         light rain  ...  10.65
# 7553   17.6868    83.2185             Rain         light rain  ...   0.81
# 7573   17.6868    83.2185     Thunderstorm       thunderstorm  ...   1.81
# 7593   17.6868    83.2185             Rain         light rain  ...  19.44
#
#         NO2     O3    SO2   PM25   PM10    NH3           CreatedAt  \
# 7     38.19  70.04  10.91  36.54  53.71   3.60 2025-06-01 12:00:00
# 27    20.16  42.95   7.57  48.00  68.64  14.81 2025-06-02 12:00:00
# 47    20.85  31.69   9.73  37.52  53.28  13.21 2025-06-03 12:00:00
# 67    54.36  56.80   4.64  63.84  91.93  14.59 2025-06-04 12:00:00
# 87     9.56  16.31  20.10  57.96  89.84  10.07 2025-06-05 12:00:00
# ...     ...    ...    ...    ...    ...    ...                 ...
# 7513  50.88  49.81  26.58  44.66  70.56  12.09 2026-06-11 12:00:00
# 7533  47.86  27.56  29.87  35.99  55.78   3.02 2026-06-12 12:00:00
# 7553  31.52  76.52  16.95  43.89  53.11   5.38 2026-06-13 12:00:00
# 7573  20.91  71.71  14.73  30.78  38.78  10.51 2026-06-14 12:00:00
# 7593  49.38  71.51  22.57  31.27  43.15   3.59 2026-06-15 12:00:00
#
#                UpdatedAt        Date
# 7    2025-06-01 12:00:00  2025-06-01
# 27   2025-06-02 12:00:00  2025-06-02
# 47   2025-06-03 12:00:00  2025-06-03
# 67   2025-06-04 12:00:00  2025-06-04
# 87   2025-06-05 12:00:00  2025-06-05
# ...                  ...         ...
# 7513 2026-06-11 12:00:00  2026-06-11
# 7533 2026-06-12 12:00:00  2026-06-12
# 7553 2026-06-13 12:00:00  2026-06-13
# 7573 2026-06-14 12:00:00  2026-06-14
# 7593 2026-06-15 12:00:00  2026-06-15
#
# [7600 rows x 36 columns]

# %% [markdown]
# ### A) Now Handle Missing Values Of "Wind Speed"

# %%
# Find rows where 'Wind Speed (m/s)' is still missing
Weather_Data[Weather_Data['WindSpeed']
            .isnull()][['WeatherCondition', 'WeatherDescription', 'WindSpeed', 'City', 'Date', 'UpdatedAt']]
# Out:
# Empty DataFrame
# Columns: [WeatherCondition, WeatherDescription, WindSpeed, City, Date, UpdatedAt]
# Index: []

# %%
# See the 'Wind Speed (m/s)' column along with other relevant columns
Weather_Data[Weather_Data['WindSpeed']
            .notnull()][['WeatherCondition', 'WeatherDescription', 'WindSpeed', 'City', 'Date', 'UpdatedAt']]
# Out:
#      WeatherCondition WeatherDescription  WindSpeed           City  \
# 7                Rain         light rain       6.16      Ahmedabad
# 27               Rain         light rain       5.18      Ahmedabad
# 47       Thunderstorm       thunderstorm       0.51      Ahmedabad
# 67              Clear          clear sky       6.37      Ahmedabad
# 87             Clouds         few clouds       3.68      Ahmedabad
# ...               ...                ...        ...            ...
# 7513     Thunderstorm       thunderstorm       3.74  Visakhapatnam
# 7533             Rain         light rain       7.19  Visakhapatnam
# 7553             Rain         light rain       4.49  Visakhapatnam
# 7573     Thunderstorm       thunderstorm       3.37  Visakhapatnam
# 7593             Rain         light rain       6.91  Visakhapatnam
#
#             Date           UpdatedAt
# 7     2025-06-01 2025-06-01 12:00:00
# 27    2025-06-02 2025-06-02 12:00:00
# 47    2025-06-03 2025-06-03 12:00:00
# 67    2025-06-04 2025-06-04 12:00:00
# 87    2025-06-05 2025-06-05 12:00:00
# ...          ...                 ...
# 7513  2026-06-11 2026-06-11 12:00:00
# 7533  2026-06-12 2026-06-12 12:00:00
# 7553  2026-06-13 2026-06-13 12:00:00
# 7573  2026-06-14 2026-06-14 12:00:00
# 7593  2026-06-15 2026-06-15 12:00:00
#
# [7600 rows x 6 columns]

# %%
# Temporarily set datetime as index for time-based interpolation
Weather_Data = Weather_Data.set_index('UpdatedAt')

# %%
# Do Time-based interpolation with filling remaining NaNs with median
Weather_Data['WindSpeed'] = (
    Weather_Data.groupby('City')['WindSpeed']
      .transform(lambda x: x.interpolate(method='time')
                            .fillna(x.median()))
)

# %%
# Restore DataFrame from index
Weather_Data = Weather_Data.reset_index()

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Date                  0
# dtype: int64

# %%
Weather_Data['WindSpeed']
# Out:
# 0       6.16
# 1       5.18
# 2       0.51
# 3       6.37
# 4       3.68
#         ...
# 7595    3.74
# 7596    7.19
# 7597    4.49
# 7598    3.37
# 7599    6.91
# Name: WindSpeed, Length: 7600, dtype: float64

# %%
Weather_Data['WindSpeed'] = Weather_Data['WindSpeed'].round(2)
Weather_Data['WindSpeed']
# Out:
# 0       6.16
# 1       5.18
# 2       0.51
# 3       6.37
# 4       3.68
#         ...
# 7595    3.74
# 7596    7.19
# 7597    4.49
# 7598    3.37
# 7599    6.91
# Name: WindSpeed, Length: 7600, dtype: float64

# %% [markdown]
# ### B) Now Handle Missing Values Of 'Wind Direction (deg)' Column Using circular interpolation

# %%
# Find rows where 'Wind Direction (degrees)' is still missing
Weather_Data[Weather_Data['WindDirection']
            .isnull()][['WeatherCondition', 'WeatherDescription', 'WindDirection', 'City', 'Date', 'UpdatedAt']]
# Out:
# Empty DataFrame
# Columns: [WeatherCondition, WeatherDescription, WindDirection, City, Date, UpdatedAt]
# Index: []

# %%
# See the 'Wind Direction (degrees)' column along with other relevant columns
Weather_Data[Weather_Data['WindDirection']
            .notnull()][['WeatherCondition', 'WeatherDescription', 'WindDirection', 'City', 'Date', 'UpdatedAt']]
# Out:
#      WeatherCondition WeatherDescription  WindDirection           City  \
# 0                Rain         light rain            322      Ahmedabad
# 1                Rain         light rain            340      Ahmedabad
# 2        Thunderstorm       thunderstorm            101      Ahmedabad
# 3               Clear          clear sky            263      Ahmedabad
# 4              Clouds         few clouds             49      Ahmedabad
# ...               ...                ...            ...            ...
# 7595     Thunderstorm       thunderstorm            250  Visakhapatnam
# 7596             Rain         light rain            114  Visakhapatnam
# 7597             Rain         light rain            108  Visakhapatnam
# 7598     Thunderstorm       thunderstorm            122  Visakhapatnam
# 7599             Rain         light rain            280  Visakhapatnam
#
#             Date           UpdatedAt
# 0     2025-06-01 2025-06-01 12:00:00
# 1     2025-06-02 2025-06-02 12:00:00
# 2     2025-06-03 2025-06-03 12:00:00
# 3     2025-06-04 2025-06-04 12:00:00
# 4     2025-06-05 2025-06-05 12:00:00
# ...          ...                 ...
# 7595  2026-06-11 2026-06-11 12:00:00
# 7596  2026-06-12 2026-06-12 12:00:00
# 7597  2026-06-13 2026-06-13 12:00:00
# 7598  2026-06-14 2026-06-14 12:00:00
# 7599  2026-06-15 2026-06-15 12:00:00
#
# [7600 rows x 6 columns]

# %%
# Now Handle Missing Values Of 'Wind Direction (deg)' Column Using circular interpolation
# Since wind direction is a circular variable (0 degrees is the same as 360 degrees),
# we will use circular interpolation to fill the missing values.

def circular_mean(series):
    vals = series.dropna()
    if len(vals) == 0:
        return series.fillna(0)
    rad = np.deg2rad(vals)
    sin_sum = np.sin(rad).mean()
    cos_sum = np.cos(rad).mean()
    
    # Calculate mean angle
    # arctan2 returns angle in radians, convert back to degrees
    # For example, if arctan2 returns -90 degrees, we convert it to 270 degrees
    mean_angle = np.rad2deg(np.arctan2(sin_sum, cos_sum)) % 360
    return series.fillna(mean_angle)

Weather_Data['WindDirection'] = (
    Weather_Data.groupby(['City','Date'])['WindDirection']
      .transform(circular_mean)
)

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Date                  0
# dtype: int64

# %%
Weather_Data['WindDirection']
# Out:
# 0       322
# 1       340
# 2       101
# 3       263
# 4        49
#        ...
# 7595    250
# 7596    114
# 7597    108
# 7598    122
# 7599    280
# Name: WindDirection, Length: 7600, dtype: int64

# %%
Weather_Data['WindDirection'] = Weather_Data['WindDirection'].round(0)
Weather_Data['WindDirection']
# Out:
# 0       322
# 1       340
# 2       101
# 3       263
# 4        49
#        ...
# 7595    250
# 7596    114
# 7597    108
# 7598    122
# 7599    280
# Name: WindDirection, Length: 7600, dtype: int64

# %% [markdown]
# ### Step 3: Fix Cloud Coverage using Weather Condition

# %%
# Find rows where 'Cloud Coverage (%)' is still missing
Weather_Data[Weather_Data['CloudCoverage']
            .isnull()][['WeatherCondition', 'WeatherDescription', 'CloudCoverage', 'City', 'Date', 'UpdatedAt']]
# Out:
# Empty DataFrame
# Columns: [WeatherCondition, WeatherDescription, CloudCoverage, City, Date, UpdatedAt]
# Index: []

# %%
# See the 'Cloud Coverage (%)' column along with other relevant columns
Weather_Data[Weather_Data['CloudCoverage']
            .notnull()][['WeatherCondition', 'WeatherDescription', 'CloudCoverage', 'City', 'Date', 'UpdatedAt']]
# Out:
#      WeatherCondition WeatherDescription  CloudCoverage           City  \
# 0                Rain         light rain             72      Ahmedabad
# 1                Rain         light rain             68      Ahmedabad
# 2        Thunderstorm       thunderstorm             87      Ahmedabad
# 3               Clear          clear sky             11      Ahmedabad
# 4              Clouds         few clouds             64      Ahmedabad
# ...               ...                ...            ...            ...
# 7595     Thunderstorm       thunderstorm             74  Visakhapatnam
# 7596             Rain         light rain             90  Visakhapatnam
# 7597             Rain         light rain             88  Visakhapatnam
# 7598     Thunderstorm       thunderstorm             93  Visakhapatnam
# 7599             Rain         light rain             84  Visakhapatnam
#
#             Date           UpdatedAt
# 0     2025-06-01 2025-06-01 12:00:00
# 1     2025-06-02 2025-06-02 12:00:00
# 2     2025-06-03 2025-06-03 12:00:00
# 3     2025-06-04 2025-06-04 12:00:00
# 4     2025-06-05 2025-06-05 12:00:00
# ...          ...                 ...
# 7595  2026-06-11 2026-06-11 12:00:00
# 7596  2026-06-12 2026-06-12 12:00:00
# 7597  2026-06-13 2026-06-13 12:00:00
# 7598  2026-06-14 2026-06-14 12:00:00
# 7599  2026-06-15 2026-06-15 12:00:00
#
# [7600 rows x 6 columns]

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Date                  0
# dtype: int64

# %%
# Step 1: City + Weather Condition median
Weather_Data['CloudCoverage'] = Weather_Data['CloudCoverage'].fillna(
    Weather_Data.groupby(['City','WeatherCondition'])['CloudCoverage']
                .transform('median')
)

# Step 2: City + Date median
Weather_Data['CloudCoverage'] = Weather_Data['CloudCoverage'].fillna(
    Weather_Data.groupby(['City','Date'])['CloudCoverage']
                .transform('median')
)

# Step 3: City median
Weather_Data['CloudCoverage'] = Weather_Data['CloudCoverage'].fillna(
    Weather_Data.groupby('City')['CloudCoverage']
                .transform('median')
)

# Step 4: Global median (final fallback)
Weather_Data['CloudCoverage'] = Weather_Data['CloudCoverage'].fillna(
    Weather_Data['CloudCoverage'].median()
)

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Date                  0
# dtype: int64

# %%
Weather_Data['CloudCoverage']
# Out:
# 0       72
# 1       68
# 2       87
# 3       11
# 4       64
#         ..
# 7595    74
# 7596    90
# 7597    88
# 7598    93
# 7599    84
# Name: CloudCoverage, Length: 7600, dtype: int64

# %%
Weather_Data['CloudCoverage'] = Weather_Data['CloudCoverage'].round(0)
Weather_Data['CloudCoverage']
# Out:
# 0       72
# 1       68
# 2       87
# 3       11
# 4       64
#         ..
# 7595    74
# 7596    90
# 7597    88
# 7598    93
# 7599    84
# Name: CloudCoverage, Length: 7600, dtype: int64

# %% [markdown]
# ### Step 4: Fix NO & NH₃

# %% [markdown]
# ### First :- Fix Only 'NO (µg/m³)'

# %%
# Find rows where 'NO (µg/m³)' is still missing
Weather_Data[Weather_Data['NO']
             .isnull()][['WeatherCondition', 'WeatherDescription', 'NO', 'City', 'Date', 'UpdatedAt']].sort_values('Date')
# Out:
# Empty DataFrame
# Columns: [WeatherCondition, WeatherDescription, NO, City, Date, UpdatedAt]
# Index: []

# %%
# See notnull 'NO (µg/m³)' column along with other relevant columns
Weather_Data[Weather_Data['NO']
             .notnull()][['WeatherCondition', 'WeatherDescription', 'NO', 'City', 'Date', 'UpdatedAt']].sort_values('Date')
# Out:
#      WeatherCondition WeatherDescription     NO           City        Date  \
# 0                Rain         light rain   4.43      Ahmedabad  2025-06-01
# 2280             Rain         light rain   2.60      Hyderabad  2025-06-01
# 760      Thunderstorm       thunderstorm  12.47         Bhopal  2025-06-01
# 2660            Clear          clear sky  18.72         Jaipur  2025-06-01
# 380              Rain         light rain  11.15      Bengaluru  2025-06-01
# ...               ...                ...    ...            ...         ...
# 5699            Clear          clear sky   4.92         Nagpur  2026-06-15
# 6079           Clouds         few clouds   0.64          Patna  2026-06-15
# 6459           Clouds         few clouds  15.42           Pune  2026-06-15
# 3419           Clouds         few clouds  19.69         Kanpur  2026-06-15
# 7599             Rain         light rain  19.44  Visakhapatnam  2026-06-15
#
#                UpdatedAt
# 0    2025-06-01 12:00:00
# 2280 2025-06-01 12:00:00
# 760  2025-06-01 12:00:00
# 2660 2025-06-01 12:00:00
# 380  2025-06-01 12:00:00
# ...                  ...
# 5699 2026-06-15 12:00:00
# 6079 2026-06-15 12:00:00
# 6459 2026-06-15 12:00:00
# 3419 2026-06-15 12:00:00
# 7599 2026-06-15 12:00:00
#
# [7600 rows x 6 columns]

# %%
# Step 1: City + Weather Description median (First It will try to fill using City and Weather Description combination)
Weather_Data['NO'] = Weather_Data['NO'].fillna(
    Weather_Data.groupby(['City','WeatherDescription'])['NO']
                .transform('median')
)

# Step 2: City + Date median (Second It will try to fill using City and Date combination)
Weather_Data['NO'] = Weather_Data['NO'].fillna(
    Weather_Data.groupby(['City','Date'])['NO'].transform('median')
)

# Step 3: City only (Third It will try to fill using only City if still NaN)
Weather_Data['NO'] = Weather_Data['NO'].fillna(
    Weather_Data.groupby('City')['NO'].transform('median')
)

# Step 4: Global median (Finally It will fill remaining NaNs with overall median)
Weather_Data['NO'] = Weather_Data['NO'].fillna(
    Weather_Data['NO'].median()
)

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Date                  0
# dtype: int64

# %%
Weather_Data['NO']
# Out:
# 0        4.43
# 1        8.74
# 2       14.69
# 3       16.81
# 4       15.13
#         ...
# 7595     5.72
# 7596    10.65
# 7597     0.81
# 7598     1.81
# 7599    19.44
# Name: NO, Length: 7600, dtype: float64

# %%
Weather_Data['NO'] = Weather_Data['NO'].round(2)
Weather_Data['NO']
# Out:
# 0        4.43
# 1        8.74
# 2       14.69
# 3       16.81
# 4       15.13
#         ...
# 7595     5.72
# 7596    10.65
# 7597     0.81
# 7598     1.81
# 7599    19.44
# Name: NO, Length: 7600, dtype: float64

# %% [markdown]
# ### Second :- Fix Only 'NH₃ (µg/m³)'

# %%
# Find rows where 'NH₃ (µg/m³)' is still missing
Weather_Data[Weather_Data['NH3']
            .isnull()][['WeatherCondition', 'WeatherDescription', 'NH3', 'City', 'Date', 'UpdatedAt']].sort_values('Date')
# Out:
# Empty DataFrame
# Columns: [WeatherCondition, WeatherDescription, NH3, City, Date, UpdatedAt]
# Index: []

# %%
# See notnull 'NH₃ (µg/m³)' column along with other relevant columns
Weather_Data[Weather_Data['NH3']
             .notnull()][['WeatherCondition', 'WeatherDescription', 'NH3', 'City', 'Date', 'UpdatedAt']].sort_values('Date')
# Out:
#      WeatherCondition WeatherDescription    NH3           City        Date  \
# 0                Rain         light rain   3.60      Ahmedabad  2025-06-01
# 2280             Rain         light rain   1.00      Hyderabad  2025-06-01
# 760      Thunderstorm       thunderstorm  14.76         Bhopal  2025-06-01
# 2660            Clear          clear sky   5.18         Jaipur  2025-06-01
# 380              Rain         light rain  10.61      Bengaluru  2025-06-01
# ...               ...                ...    ...            ...         ...
# 5699            Clear          clear sky   5.62         Nagpur  2026-06-15
# 6079           Clouds         few clouds   9.38          Patna  2026-06-15
# 6459           Clouds         few clouds   5.76           Pune  2026-06-15
# 3419           Clouds         few clouds   5.91         Kanpur  2026-06-15
# 7599             Rain         light rain   3.59  Visakhapatnam  2026-06-15
#
#                UpdatedAt
# 0    2025-06-01 12:00:00
# 2280 2025-06-01 12:00:00
# 760  2025-06-01 12:00:00
# 2660 2025-06-01 12:00:00
# 380  2025-06-01 12:00:00
# ...                  ...
# 5699 2026-06-15 12:00:00
# 6079 2026-06-15 12:00:00
# 6459 2026-06-15 12:00:00
# 3419 2026-06-15 12:00:00
# 7599 2026-06-15 12:00:00
#
# [7600 rows x 6 columns]

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Date                  0
# dtype: int64

# %%
# Step 1: City + Weather Description median (First It will try to fill using City and Weather Description combination)
Weather_Data['NH3'] = Weather_Data['NH3'].fillna(
    Weather_Data.groupby(['City','WeatherDescription'])['NH3']
                .transform('median')
)

# Step 2: City + Date median (Second It will try to fill using City and Date combination)
Weather_Data['NH3'] = Weather_Data['NH3'].fillna(
    Weather_Data.groupby(['City','Date'])['NH3'].transform('median')
)

# Step 3: City only (Third It will try to fill using only City if still NaN)
Weather_Data['NH3'] = Weather_Data['NH3'].fillna(
    Weather_Data.groupby('City')['NH3'].transform('median')
)

# Step 4: Global median (Finally It will fill remaining NaNs with overall median)
Weather_Data['NH3'] = Weather_Data['NH3'].fillna(
    Weather_Data['NH3'].median()
)

# %%
# Check missing values
print(Weather_Data.isnull().sum())
# Out:
# UpdatedAt             0
# Country               0
# CountryCode           0
# State                 0
# StateCode             0
# City                  0
# CityID                0
# Latitude              0
# Longitude             0
# WeatherCondition      0
# WeatherDescription    0
# WeatherCode           0
# Temperature           0
# FeelsLike             0
# TempMin               0
# TempMax               0
# Pressure              0
# Humidity              0
# SeaLevel              0
# GroundLevel           0
# WindSpeed             0
# WindDirection         0
# WindGust              0
# CloudCoverage         0
# Visibility            0
# AQI                   0
# CO                    0
# NO                    0
# NO2                   0
# O3                    0
# SO2                   0
# PM25                  0
# PM10                  0
# NH3                   0
# CreatedAt             0
# Date                  0
# dtype: int64

# %%
Weather_Data['NH3']
# Out:
# 0        3.60
# 1       14.81
# 2       13.21
# 3       14.59
# 4       10.07
#         ...
# 7595    12.09
# 7596     3.02
# 7597     5.38
# 7598    10.51
# 7599     3.59
# Name: NH3, Length: 7600, dtype: float64

# %%
Weather_Data['NH3'] = Weather_Data['NH3'].round(2)
Weather_Data['NH3']
# Out:
# 0        3.60
# 1       14.81
# 2       13.21
# 3       14.59
# 4       10.07
#         ...
# 7595    12.09
# 7596     3.02
# 7597     5.38
# 7598    10.51
# 7599     3.59
# Name: NH3, Length: 7600, dtype: float64

# %%
# Count duplicates if any
duplicate_count = Weather_Data.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
Weather_Data
# Out:
#                UpdatedAt Country CountryCode           State StateCode  \
# 0    2025-06-01 12:00:00   India          IN         Gujarat        GJ
# 1    2025-06-02 12:00:00   India          IN         Gujarat        GJ
# 2    2025-06-03 12:00:00   India          IN         Gujarat        GJ
# 3    2025-06-04 12:00:00   India          IN         Gujarat        GJ
# 4    2025-06-05 12:00:00   India          IN         Gujarat        GJ
# ...                  ...     ...         ...             ...       ...
# 7595 2026-06-11 12:00:00   India          IN  Andhra Pradesh        AP
# 7596 2026-06-12 12:00:00   India          IN  Andhra Pradesh        AP
# 7597 2026-06-13 12:00:00   India          IN  Andhra Pradesh        AP
# 7598 2026-06-14 12:00:00   India          IN  Andhra Pradesh        AP
# 7599 2026-06-15 12:00:00   India          IN  Andhra Pradesh        AP
#
#                City   CityID  Latitude  Longitude WeatherCondition  ...  \
# 0         Ahmedabad  1279233   23.0225    72.5714             Rain  ...
# 1         Ahmedabad  1279233   23.0225    72.5714             Rain  ...
# 2         Ahmedabad  1279233   23.0225    72.5714     Thunderstorm  ...
# 3         Ahmedabad  1279233   23.0225    72.5714            Clear  ...
# 4         Ahmedabad  1279233   23.0225    72.5714           Clouds  ...
# ...             ...      ...       ...        ...              ...  ...
# 7595  Visakhapatnam  1252783   17.6868    83.2185     Thunderstorm  ...
# 7596  Visakhapatnam  1252783   17.6868    83.2185             Rain  ...
# 7597  Visakhapatnam  1252783   17.6868    83.2185             Rain  ...
# 7598  Visakhapatnam  1252783   17.6868    83.2185     Thunderstorm  ...
# 7599  Visakhapatnam  1252783   17.6868    83.2185             Rain  ...
#
#            CO     NO    NO2     O3    SO2   PM25   PM10    NH3  \
# 0     1027.56   4.43  38.19  70.04  10.91  36.54  53.71   3.60
# 1     1277.53   8.74  20.16  42.95   7.57  48.00  68.64  14.81
# 2      700.34  14.69  20.85  31.69   9.73  37.52  53.28  13.21
# 3      997.65  16.81  54.36  56.80   4.64  63.84  91.93  14.59
# 4      809.84  15.13   9.56  16.31  20.10  57.96  89.84  10.07
# ...       ...    ...    ...    ...    ...    ...    ...    ...
# 7595   455.98   5.72  50.88  49.81  26.58  44.66  70.56  12.09
# 7596   663.68  10.65  47.86  27.56  29.87  35.99  55.78   3.02
# 7597  1068.09   0.81  31.52  76.52  16.95  43.89  53.11   5.38
# 7598  1452.75   1.81  20.91  71.71  14.73  30.78  38.78  10.51
# 7599  1204.52  19.44  49.38  71.51  22.57  31.27  43.15   3.59
#
#                CreatedAt        Date
# 0    2025-06-01 12:00:00  2025-06-01
# 1    2025-06-02 12:00:00  2025-06-02
# 2    2025-06-03 12:00:00  2025-06-03
# 3    2025-06-04 12:00:00  2025-06-04
# 4    2025-06-05 12:00:00  2025-06-05
# ...                  ...         ...
# 7595 2026-06-11 12:00:00  2026-06-11
# 7596 2026-06-12 12:00:00  2026-06-12
# 7597 2026-06-13 12:00:00  2026-06-13
# 7598 2026-06-14 12:00:00  2026-06-14
# 7599 2026-06-15 12:00:00  2026-06-15
#
# [7600 rows x 36 columns]

# %% [markdown]
# ### STEP 1: Ensure pollutant columns are numeric

# %%
# pollutant_columns = [
#     "CO", "NO", "NO2", "O3",
#     "SO2", "PM25", "PM10", "NH3"
# ]

# Weather_Data[pollutant_columns] = Weather_Data[pollutant_columns].apply(
#     pd.to_numeric, errors="coerce"
# )

# %% [markdown]
# ### STEP 2: Define CPCB AQI Breakpoints (CPCB – INDIA)

# %%
# AQI_BREAKPOINTS = {
#     "PM25": [(0,30,0,50),(31,60,51,100),(61,90,101,200),
#               (91,120,201,300),(121,250,301,400),(251,500,401,500)],

#     "PM10": [(0,50,0,50),(51,100,51,100),(101,250,101,200),
#              (251,350,201,300),(351,430,301,400),(431,600,401,500)],

#     "NO2": [(0,40,0,50),(41,80,51,100),(81,180,101,200),
#             (181,280,201,300),(281,400,301,400),(401,1000,401,500)],

#     "SO2": [(0,40,0,50),(41,80,51,100),(81,380,101,200),
#             (381,800,201,300),(801,1600,301,400),(1601,2000,401,500)],

#     "CO": [(0,1.0,0,50),(1.1,2.0,51,100),(2.1,10,101,200),
#            (10.1,17,201,300),(17.1,34,301,400),(34.1,50,401,500)],

#     "O3": [(0,50,0,50),(51,100,51,100),(101,168,101,200),
#            (169,208,201,300),(209,748,301,400),(749,1000,401,500)],

#     "NH3": [(0,200,0,50),(201,400,51,100),(401,800,101,200),
#             (801,1200,201,300),(1201,1800,301,400),(1801,3000,401,500)]
# }

# %% [markdown]
# ### STEP 3: Mapping

# %%
# COLUMN_MAP = {
#     "PM25": "PM25",
#     "PM10": "PM10",
#     "NO2": "NO2",
#     "SO2": "SO2",
#     "CO": "CO",
#     "O3": "O3",
#     "NH3": "NH3"
# }

# %% [markdown]
# ### STEP 4: Sub-AQI calculation

# %%
# # Sub-AQI calculation function
# def calculate_sub_aqi(pollutant, concentration):
#     if pd.isna(concentration):
#         return None

#     for bp_lo, bp_hi, i_lo, i_hi in AQI_BREAKPOINTS[pollutant]:
#         if bp_lo <= concentration <= bp_hi:
#             return round(
#                 ((i_hi - i_lo) / (bp_hi - bp_lo)) *
#                 (concentration - bp_lo) + i_lo
#             )
#     return None

# %% [markdown]
# ### STEP 6: Final AQI calculation

# %%
# # Final AQI calculation (dominant pollutant logic)
# def calculate_final_aqi(row):
#     sub_aqis = []

#     for pollutant, column in COLUMN_MAP.items():
#         value = row[column]
#         sub = calculate_sub_aqi(pollutant, value)
#         if sub is not None:
#             sub_aqis.append(sub)

#     if len(sub_aqis) < 3:   # CPCB minimum requirement
#         return None

#     return max(sub_aqis)

# %% [markdown]
# ### STEP 7: Create Final AQI column

# %%
# Weather_Data["Final_AQI"] = Weather_Data.apply(calculate_final_aqi, axis=1)

# %%
# Weather_Data["Final_AQI"]

# %% [markdown]
# ### STEP 8: AQI Category column

# %%
# def aqi_category(aqi):
#     if pd.isna(aqi): return None
#     if aqi <= 50: return "Good"
#     if aqi <= 100: return "Satisfactory"
#     if aqi <= 200: return "Moderate"
#     if aqi <= 300: return "Poor"
#     if aqi <= 400: return "Very Poor"
#     return "Severe"

# Weather_Data["AQI_Category"] = Weather_Data["Final_AQI"].apply(aqi_category)

# %% [markdown]
# ### STEP 9: Final check

# %%
# Weather_Data[["City", "Final_AQI", "AQI_Category"]]

# %% [markdown]
# ### Step 3: Descriptive Statistics

# %%
# Summary statistics for numerical columns
Weather_Data.describe()
# Out:
#                  UpdatedAt        CityID     Latitude    Longitude  \
# count                 7600  7.600000e+03  7600.000000  7600.000000
# mean   2025-12-08 00:00:00  1.266262e+06    20.357720    78.299435
# min    2025-06-01 12:00:00  1.252783e+06     9.931200    72.571400
# 25%    2025-09-04 06:00:00  1.259872e+06    16.863575    75.371475
# 50%    2025-12-08 00:00:00  1.266362e+06    21.158000    77.503600
# 75%    2026-03-12 18:00:00  1.273722e+06    25.386725    80.485475
# max    2026-06-15 12:00:00  1.279233e+06    28.613900    88.363900
# std                    NaN  8.022117e+03     5.440234     4.211750
#
#        WeatherCode  Temperature    FeelsLike      TempMin      TempMax  \
# count  7600.000000  7600.000000  7600.000000  7600.000000  7600.000000
# mean    682.549605    27.841437    27.820221    21.489605    34.001447
# min     211.000000     6.910000     5.940000     6.000000    21.000000
# 25%     500.000000    24.040000    23.840000    18.000000    30.000000
# 50%     800.000000    28.295000    28.160000    23.000000    34.000000
# 75%     800.000000    32.212500    32.260000    27.000000    38.000000
# max     801.000000    44.550000    45.420000    30.000000    45.000000
# std     192.548151     6.584679     6.690285     6.097998     5.373079
#
#           Pressure  ...          AQI           CO           NO          NO2  \
# count  7600.000000  ...  7600.000000  7600.000000  7600.000000  7600.000000
# mean   1010.031842  ...   111.558684   859.246747    10.027809    32.697207
# min     995.000000  ...    15.000000   200.110000     0.000000     5.000000
# 25%    1003.000000  ...    67.000000   543.200000     5.017500    18.635000
# 50%    1010.000000  ...    99.000000   862.755000    10.020000    32.830000
# 75%    1018.000000  ...   140.000000  1178.742500    15.040000    46.680000
# max    1025.000000  ...   400.000000  1499.990000    20.000000    59.990000
# std       8.689314  ...    61.454196   372.403528     5.794989    16.043552
#
#                 O3          SO2         PM25         PM10          NH3  \
# count  7600.000000  7600.000000  7600.000000  7600.000000  7600.000000
# mean     45.141942    16.130618    55.731659    78.051617     7.951322
# min      10.000000     2.000000     6.150000     8.320000     1.000000
# 25%      27.667500     9.230000    33.280000    45.900000     4.480000
# 50%      45.160000    16.080000    49.200000    68.755000     7.845000
# 75%      62.402500    23.062500    70.400000    98.800000    11.430000
# max      79.990000    30.000000   227.430000   339.890000    15.000000
# std      20.127652     8.028715    31.622628    44.831824     4.022727
#
#                  CreatedAt
# count                 7600
# mean   2025-12-08 00:00:00
# min    2025-06-01 12:00:00
# 25%    2025-09-04 06:00:00
# 50%    2025-12-08 00:00:00
# 75%    2026-03-12 18:00:00
# max    2026-06-15 12:00:00
# std                    NaN
#
# [8 rows x 28 columns]

# %%
# Unique cities & states
print("Unique cities:", Weather_Data['City'].nunique(), "\nUnique states:", Weather_Data['State'].nunique())
# Out:
# Unique cities: 20
# Unique states: 14

# %%
# Show the countries, states, and cities name in the dataset
Weather_Data[['Country', 'State', 'City']]
# Out:
#      Country           State           City
# 0      India         Gujarat      Ahmedabad
# 1      India         Gujarat      Ahmedabad
# 2      India         Gujarat      Ahmedabad
# 3      India         Gujarat      Ahmedabad
# 4      India         Gujarat      Ahmedabad
# ...      ...             ...            ...
# 7595   India  Andhra Pradesh  Visakhapatnam
# 7596   India  Andhra Pradesh  Visakhapatnam
# 7597   India  Andhra Pradesh  Visakhapatnam
# 7598   India  Andhra Pradesh  Visakhapatnam
# 7599   India  Andhra Pradesh  Visakhapatnam
#
# [7600 rows x 3 columns]

# %%
# Frequency of weather conditions
Weather_Data['WeatherCondition'].value_counts()
# Out:
# WeatherCondition
# Clear           3052
# Clouds          1791
# Rain            1286
# Thunderstorm     766
# Mist             377
# Haze             190
# Heat Wave         65
# Cold Wave         60
# Dust              13
# Name: count, dtype: int64

# %%
Weather_Data.head(10)
# Out:
#             UpdatedAt Country CountryCode    State StateCode       City  \
# 0 2025-06-01 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 1 2025-06-02 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 2 2025-06-03 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 3 2025-06-04 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 4 2025-06-05 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 5 2025-06-06 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 6 2025-06-07 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 7 2025-06-08 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 8 2025-06-09 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 9 2025-06-10 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
#
#     CityID  Latitude  Longitude WeatherCondition  ...       CO     NO    NO2  \
# 0  1279233   23.0225    72.5714             Rain  ...  1027.56   4.43  38.19
# 1  1279233   23.0225    72.5714             Rain  ...  1277.53   8.74  20.16
# 2  1279233   23.0225    72.5714     Thunderstorm  ...   700.34  14.69  20.85
# 3  1279233   23.0225    72.5714            Clear  ...   997.65  16.81  54.36
# 4  1279233   23.0225    72.5714           Clouds  ...   809.84  15.13   9.56
# 5  1279233   23.0225    72.5714             Rain  ...   891.53   4.75  24.08
# 6  1279233   23.0225    72.5714           Clouds  ...  1296.19  11.01  44.86
# 7  1279233   23.0225    72.5714            Clear  ...  1319.97  10.94  24.61
# 8  1279233   23.0225    72.5714             Rain  ...  1076.20   4.49  10.40
# 9  1279233   23.0225    72.5714     Thunderstorm  ...   957.88   8.90  16.48
#
#       O3    SO2   PM25   PM10    NH3           CreatedAt        Date
# 0  70.04  10.91  36.54  53.71   3.60 2025-06-01 12:00:00  2025-06-01
# 1  42.95   7.57  48.00  68.64  14.81 2025-06-02 12:00:00  2025-06-02
# 2  31.69   9.73  37.52  53.28  13.21 2025-06-03 12:00:00  2025-06-03
# 3  56.80   4.64  63.84  91.93  14.59 2025-06-04 12:00:00  2025-06-04
# 4  16.31  20.10  57.96  89.84  10.07 2025-06-05 12:00:00  2025-06-05
# 5  21.22   6.34  45.36  66.68   9.96 2025-06-06 12:00:00  2025-06-06
# 6  12.09  27.90  34.84  52.26  11.81 2025-06-07 12:00:00  2025-06-07
# 7  70.82  24.31  56.58  70.72   6.61 2025-06-08 12:00:00  2025-06-08
# 8  65.71  15.58  44.29  54.03   4.14 2025-06-09 12:00:00  2025-06-09
# 9  59.95  17.68  49.59  66.45  12.64 2025-06-10 12:00:00  2025-06-10
#
# [10 rows x 36 columns]

# %% [markdown]
# ### Step 4: Weather Analysis

# %% [markdown]
# ### Viz 1: Temperature distribution

# %%
# Here we visualize the temperature distribution using a histogram with a KDE overlay.
# Frequency represents how often each temperature range occurs in the dataset.
# kde stands for Kernel Density Estimate, which provides a smooth estimate of the distribution.
# kde=True adds the KDE line to the histogram.
sns.histplot(Weather_Data['Temperature'], kde=True)
plt.title("Temperature Distribution")
plt.xlabel("Temperature (°C)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Viz 2: Wind speed distribution

# %%
# Wind speed distribution
sns.histplot(Weather_Data['WindSpeed'])
plt.title("Wind Speed Distribution")
plt.xlabel("WindSpeed")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Viz 3: Average temperature vs Cloud Coverage

# %%
# Average temperature vs Cloud Coverage
avg_temp_by_cloud = Weather_Data.groupby('CloudCoverage')['Temperature'].mean()
sns.jointplot(
    data=Weather_Data,
    x='CloudCoverage',
    y=avg_temp_by_cloud,
    kind='scatter',
    color='b'
)
plt.suptitle('Cloud Coverage (%) vs. Avg. Temperature (°C)', y=1.02)
plt.show()

# %% [markdown]
# ### Viz 4.1: Time of count for each Weather condition

# %%
# Time of count for each Weather condition 
# kind='bar' specifies that we want a bar plot.
Weather_Data['WeatherCondition'].value_counts().plot(kind='bar', figsize=(10,5))
plt.title("Weather Condition Frequency")
plt.xlabel("Weather Condition")
plt.ylabel("Total Number of Times")
plt.show()

# %% [markdown]
# ### Viz 4.2: Top 5 cities with highest Haze days

# %%
# Find top 5 cities with highest Haze days
haze_days = Weather_Data[Weather_Data['WeatherCondition'] == 'Haze'].copy()
haze_days_count = haze_days.groupby('City').size().sort_values(ascending=False).head(10)
haze_days_count.plot(kind='bar', figsize=(10,5))
plt.title("Top 10 Cities with Highest Haze Days")
plt.xlabel("City")
plt.ylabel("Number of Haze Days")
plt.show()

# %% [markdown]
# ### Viz 4.3: "Pune" has Highest Haze Occurrence

# %%
Weather_Data
# Out:
#                UpdatedAt Country CountryCode           State StateCode  \
# 0    2025-06-01 12:00:00   India          IN         Gujarat        GJ
# 1    2025-06-02 12:00:00   India          IN         Gujarat        GJ
# 2    2025-06-03 12:00:00   India          IN         Gujarat        GJ
# 3    2025-06-04 12:00:00   India          IN         Gujarat        GJ
# 4    2025-06-05 12:00:00   India          IN         Gujarat        GJ
# ...                  ...     ...         ...             ...       ...
# 7595 2026-06-11 12:00:00   India          IN  Andhra Pradesh        AP
# 7596 2026-06-12 12:00:00   India          IN  Andhra Pradesh        AP
# 7597 2026-06-13 12:00:00   India          IN  Andhra Pradesh        AP
# 7598 2026-06-14 12:00:00   India          IN  Andhra Pradesh        AP
# 7599 2026-06-15 12:00:00   India          IN  Andhra Pradesh        AP
#
#                City   CityID  Latitude  Longitude WeatherCondition  ...  \
# 0         Ahmedabad  1279233   23.0225    72.5714             Rain  ...
# 1         Ahmedabad  1279233   23.0225    72.5714             Rain  ...
# 2         Ahmedabad  1279233   23.0225    72.5714     Thunderstorm  ...
# 3         Ahmedabad  1279233   23.0225    72.5714            Clear  ...
# 4         Ahmedabad  1279233   23.0225    72.5714           Clouds  ...
# ...             ...      ...       ...        ...              ...  ...
# 7595  Visakhapatnam  1252783   17.6868    83.2185     Thunderstorm  ...
# 7596  Visakhapatnam  1252783   17.6868    83.2185             Rain  ...
# 7597  Visakhapatnam  1252783   17.6868    83.2185             Rain  ...
# 7598  Visakhapatnam  1252783   17.6868    83.2185     Thunderstorm  ...
# 7599  Visakhapatnam  1252783   17.6868    83.2185             Rain  ...
#
#            CO     NO    NO2     O3    SO2   PM25   PM10    NH3  \
# 0     1027.56   4.43  38.19  70.04  10.91  36.54  53.71   3.60
# 1     1277.53   8.74  20.16  42.95   7.57  48.00  68.64  14.81
# 2      700.34  14.69  20.85  31.69   9.73  37.52  53.28  13.21
# 3      997.65  16.81  54.36  56.80   4.64  63.84  91.93  14.59
# 4      809.84  15.13   9.56  16.31  20.10  57.96  89.84  10.07
# ...       ...    ...    ...    ...    ...    ...    ...    ...
# 7595   455.98   5.72  50.88  49.81  26.58  44.66  70.56  12.09
# 7596   663.68  10.65  47.86  27.56  29.87  35.99  55.78   3.02
# 7597  1068.09   0.81  31.52  76.52  16.95  43.89  53.11   5.38
# 7598  1452.75   1.81  20.91  71.71  14.73  30.78  38.78  10.51
# 7599  1204.52  19.44  49.38  71.51  22.57  31.27  43.15   3.59
#
#                CreatedAt        Date
# 0    2025-06-01 12:00:00  2025-06-01
# 1    2025-06-02 12:00:00  2025-06-02
# 2    2025-06-03 12:00:00  2025-06-03
# 3    2025-06-04 12:00:00  2025-06-04
# 4    2025-06-05 12:00:00  2025-06-05
# ...                  ...         ...
# 7595 2026-06-11 12:00:00  2026-06-11
# 7596 2026-06-12 12:00:00  2026-06-12
# 7597 2026-06-13 12:00:00  2026-06-13
# 7598 2026-06-14 12:00:00  2026-06-14
# 7599 2026-06-15 12:00:00  2026-06-15
#
# [7600 rows x 36 columns]

# %%
# Find out when "Pune" has Highest Haze Occurrence based on months name
pune_haze = Weather_Data[(Weather_Data['City'] == 'Pune') & (Weather_Data['WeatherCondition'] == 'Haze')].copy()
pune_haze['Month'] = pd.to_datetime(pune_haze['Date']).dt.month_name()
pune_haze_monthly = pune_haze.groupby('Month').size().sort_values(ascending=False)
pune_haze_monthly.plot(kind='bar', figsize=(10,5))
plt.title("Top Months with Highest Haze Occurrence in Pune")
plt.xlabel("Month")
plt.ylabel("Number of Haze Observations")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Viz 4.4: PM2.5 Levels on Haze vs Non-Haze Days (Pune)

# %%
pune_data = Weather_Data[Weather_Data['City'] == 'Pune'].copy()

pune_data['Haze_Flag'] = pune_data['WeatherCondition'].apply(
    lambda x: 'Haze' if x == 'Haze' else 'Non-Haze'
)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(
    data=pune_data,
    x='Haze_Flag',
    y='PM25',
    color='purple', 
)
plt.title('PM2.5 Levels on Haze vs Non-Haze Days (Pune)')
plt.xlabel('Haze Flag')
plt.ylabel('PM2.5')
plt.show()

# %% [markdown]
# ### Viz 4.5: Humidity (%) on Haze vs Non-Haze Days (Kolkata)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(
    data=pune_data,
    x='Haze_Flag',
    y='Humidity',
    color='lightblue'
)
plt.title('Humidity on Haze vs Non-Haze Days (Ahmedabad)')
plt.xlabel('')
plt.ylabel('Humidity')
plt.show()

# %% [markdown]
# ### Viz 4.6: HWind Speed (m/s) on Haze vs Non-Haze Days (Pune)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(
    data=pune_data,
    x='Haze_Flag',
    y='WindSpeed',
    color='lightgreen'
)
plt.title('Wind Speed on Haze vs Non-Haze Days (Pune)')
plt.xlabel('')
plt.ylabel('Wind Speed (m/s)')
plt.show()

# %% [markdown]
# ### Viz 5: Observations of Humidity (%) in Kolkata Over Time

# %%
# Find out the observations of Humidity (%) in Kolkata Over Time
kolkata_data = Weather_Data[(Weather_Data['City'] == 'Kolkata')].copy()
plt.figure(figsize=(20, 5))
sns.lineplot(x='Date', y='Humidity', data=kolkata_data, color='cyan')
plt.suptitle("Humidity (%) in Kolkata Over Time", y=1.02)
plt.show()

# %% [markdown]
# ### Viz 6: Observations of PM2.5 & PM10 Levels in Kolkata Over Time

# %%
# Find out the observations of PM2.5, PM10 Levels in Kolkata Over Time based on months
# Create Month column
kolkata_data['Month'] = pd.to_datetime(kolkata_data['Date']).dt.to_period('M').astype(str)

# Monthly averages
monthly_data = (kolkata_data.groupby('Month')[['PM25', 'PM10']].mean().reset_index())

plt.figure(figsize=(20, 5))
sns.lineplot(x='Month',y='PM25',data=monthly_data,color='lightcoral',label='PM2.5')
sns.lineplot(x='Month',y='PM10',data=monthly_data,color='darkblue',label='PM10')
plt.title("Monthly Average PM2.5 and PM10 Levels in Kolkata",fontsize=16)

plt.xlabel("Month")
plt.ylabel("Concentration (µg/m³)")
plt.xticks(rotation=45)
plt.legend(title='Pollutant')

plt.show()

# %% [markdown]
# ### Viz 7.1: Top 5 Hottest Cities by Average Temperature
# ### Viz 7.2: Top 5 Coldest Cities by Average Temperature

# %%
# Calculate average temperature per city
avg_temp_city = (Weather_Data.groupby('City', as_index=False)['Temperature'].mean())

# Top 5 hottest cities
top_5_hot = avg_temp_city.sort_values(by='Temperature', ascending=False).head(5)

# Top 5 coldest cities
top_5_cold = avg_temp_city.sort_values(by='Temperature', ascending=True).head(5)

# Create subplots
fig, axes = plt.subplots(2, 1, figsize=(10, 15))

# ____Hot cities plot___
ax1 = sns.barplot(
    data=top_5_hot,
    x='City',
    y='Temperature',
    color='red',
    ax=axes[0], 
    width=0.5
)
axes[0].set_title('Top 5 Hottest Cities by Average Temperature', fontsize=16)
axes[0].set_xlabel('City', fontsize=14)
axes[0].set_ylabel('Average Temperature (°C)', fontsize=14)
axes[0].bar_label(ax1.containers[0], fmt='%.1f°C', fontsize=12)

axes[0].tick_params(axis='x', labelsize=12)
axes[0].tick_params(axis='y', labelsize=12)

# ___Cold cities plot____
ax2 = sns.barplot(
    data=top_5_cold,
    x='City',
    y='Temperature',
    color='blue',
    ax=axes[1],
    width=0.5
)
axes[1].set_title('Top 5 Coldest Cities by Average Temperature', fontsize=16)
axes[1].set_xlabel('City', fontsize=14)
axes[1].set_ylabel('Average Temperature (°C)', fontsize=14)
axes[1].bar_label(ax2.containers[0], fmt='%.1f°C', fontsize=12)

axes[1].tick_params(axis='x', labelsize=12)
axes[1].tick_params(axis='y', labelsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Viz 8.1: Top 5 Coldest States by Average Temperature
# ### Viz 8.2: Top 5 Coldest States by Average Temperature

# %%
# Calculate average temperature per state
avg_temp_state = (Weather_Data.groupby('State', as_index=False)['Temperature'].mean())

# Top 5 hottest states
top_5_hot = avg_temp_state.sort_values(by='Temperature', ascending=False).head(5)

# Top 5 coldest states
top_5_cold = avg_temp_state.sort_values(by='Temperature', ascending=True).head(5)

# Create subplots
fig, axes = plt.subplots(2, 1, figsize=(10, 15))

# ____Hot states plot___
ax1 = sns.barplot(
    data=top_5_hot,
    x='State',
    y='Temperature',
    color='orange',
    ax=axes[0], 
    width=0.5
)
axes[0].set_title('Top 5 Hottest States by Average Temperature', fontsize=16)
axes[0].set_xlabel('State', fontsize=14)
axes[0].set_ylabel('Average Temperature (°C)', fontsize=14)
axes[0].bar_label(ax1.containers[0], fmt='%.1f°C', fontsize=12)

axes[0].tick_params(axis='x', labelsize=12)
axes[0].tick_params(axis='y', labelsize=12)

# ___Cold states plot____
ax2 = sns.barplot(
    data=top_5_cold,
    x='State',
    y='Temperature',
    color='cyan',
    ax=axes[1],
    width=0.5
)
axes[1].set_title('Top 5 Coldest States by Average Temperature', fontsize=16)
axes[1].set_xlabel('State', fontsize=14)
axes[1].set_ylabel('Average Temperature (°C)', fontsize=14)
axes[1].bar_label(ax2.containers[0], fmt='%.1f°C', fontsize=12)

axes[1].tick_params(axis='x', labelsize=12)
axes[1].tick_params(axis='y', labelsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 5: Pollution Analysis

# %%
Weather_Data.head()
# Out:
#             UpdatedAt Country CountryCode    State StateCode       City  \
# 0 2025-06-01 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 1 2025-06-02 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 2 2025-06-03 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 3 2025-06-04 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 4 2025-06-05 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
#
#     CityID  Latitude  Longitude WeatherCondition  ...       CO     NO    NO2  \
# 0  1279233   23.0225    72.5714             Rain  ...  1027.56   4.43  38.19
# 1  1279233   23.0225    72.5714             Rain  ...  1277.53   8.74  20.16
# 2  1279233   23.0225    72.5714     Thunderstorm  ...   700.34  14.69  20.85
# 3  1279233   23.0225    72.5714            Clear  ...   997.65  16.81  54.36
# 4  1279233   23.0225    72.5714           Clouds  ...   809.84  15.13   9.56
#
#       O3    SO2   PM25   PM10    NH3           CreatedAt        Date
# 0  70.04  10.91  36.54  53.71   3.60 2025-06-01 12:00:00  2025-06-01
# 1  42.95   7.57  48.00  68.64  14.81 2025-06-02 12:00:00  2025-06-02
# 2  31.69   9.73  37.52  53.28  13.21 2025-06-03 12:00:00  2025-06-03
# 3  56.80   4.64  63.84  91.93  14.59 2025-06-04 12:00:00  2025-06-04
# 4  16.31  20.10  57.96  89.84  10.07 2025-06-05 12:00:00  2025-06-05
#
# [5 rows x 36 columns]

# %%
# Map AQI values to categories using range-based mapping
def aqi_category(aqi):
    if pd.isna(aqi):
        return None
    elif aqi <= 50:
        return 'Good'
    elif aqi <= 100:
        return 'Satisfactory'
    elif aqi <= 200:
        return 'Moderate'
    elif aqi <= 300:
        return 'Poor'
    elif aqi <= 400:
        return 'Very Poor'
    else:
        return 'Severe'

Weather_Data['AQI_Category'] = Weather_Data['AQI'].map(aqi_category)

# %%
Weather_Data[['AQI','AQI_Category']]
# Out:
#       AQI  AQI_Category
# 0      63  Satisfactory
# 1      96  Satisfactory
# 2      67  Satisfactory
# 3     112      Moderate
# 4     126      Moderate
# ...   ...           ...
# 7595   77  Satisfactory
# 7596   61  Satisfactory
# 7597   77  Satisfactory
# 7598   54  Satisfactory
# 7599   59  Satisfactory
#
# [7600 rows x 2 columns]

# %% [markdown]
# ### Viz 1: Percentage Distribution of AQI Categories

# %%
aqi_order = ['Good', 'Satisfactory', 'Moderate', 'Poor', 'Very Poor', 'Severe']

aqi_dist = (
    Weather_Data['AQI_Category']
    .value_counts(normalize=True)
    .reindex(aqi_order) * 100
)

plt.figure(figsize=(8,5))
sns.barplot(
    x=aqi_dist.index,
    y=aqi_dist.values,
    palette='viridis'
)

plt.title('Percentage Distribution of AQI Categories')
plt.xlabel('AQI Category')
plt.ylabel('Percentage of Records (%)')
plt.show()
# Out:
# C:\Users\kundu\AppData\Local\Temp\ipykernel_1276\2653360008.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### Viz 2: Top polluted cities by PM2.5
#
# 1. Here, we group the data by 'City Name' and calculate the mean PM2.5 for each city.
#
# 2. We then sort the cities by their average PM2.5 in descending order and select the top 10.
#
# 3. Finally, we print the top 10 cities with the highest average PM2.5 levels.

# %%
# axis_index=False ensures that 'City Name' remains a column after grouping.
# acscending=False sorts the values from highest to lowest.
top_pm25 = (
    Weather_Data.groupby('City', as_index=False)['PM25']
    .mean()
    .sort_values(by='PM25', ascending=False)
    .head(10)
)

print("Top 10 cities by average PM2.5:")
print(top_pm25)
# Out:
# Top 10 cities by average PM2.5:
#          City       PM25
# 8      Kanpur  87.778342
# 4       Delhi  85.424342
# 11    Lucknow  81.354053
# 18   Varanasi  79.190895
# 7      Jaipur  77.915579
# 10    Kolkata  74.328789
# 15      Patna  74.258868
# 2      Bhopal  64.445684
# 14     Nagpur  62.807184
# 0   Ahmedabad  60.915263

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='PM25', y='City', data=top_pm25, palette='Reds_r')
plt.title("Top 10 Most Polluted Cities (PM2.5 Concentration)")
plt.xlabel("PM2.5 (µg/m³)")
plt.ylabel("City Name")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kundu\AppData\Local\Temp\ipykernel_1276\2004844121.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PM25', y='City', data=top_pm25, palette='Reds_r')

# %% [markdown]
# ### Viz 3: Correlation heatmap of pollutants

# %%
# Correlation heatmap of pollutants
pollutants = ['CO','NO','NO2','O3','SO2','PM25','PM10','NH3', 'AQI']

# here figsize sets the size of the figure
# annot=True adds the correlation values on the heatmap
# cmap='coolwarm' sets the color scheme of the heatmap
plt.figure(figsize=(10,6))
sns.heatmap(Weather_Data[pollutants].corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Pollutant Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Viz 4: Top 5 cities that produce most PM2.5 & PM10 particulate matter

# %%
# Find out top 5 cities that produce most PM2.5 & PM10 particulate matter
top_5_pm25_cities = Weather_Data.groupby('City')['PM25'].mean().sort_values(ascending=False).head(5)
top_5_pm10_cities = Weather_Data.groupby('City')['PM10'].mean().sort_values(ascending=False).head(5)

# Show them by using plot
fig, axes = plt.subplots(2, 1, figsize=(10, 15))
top_5_pm25_cities.plot(kind='bar', color='purple', ax=axes[0])
axes[0].set_title("Top 5 Cities by Average PM2.5")
axes[0].set_xlabel("City")
axes[0].set_ylabel("Average PM2.5 (µg/m³)")

top_5_pm10_cities.plot(kind='bar', color='brown', ax=axes[1])
axes[1].set_title("Top 5 Cities by Average PM10")
axes[1].set_xlabel("City")
axes[1].set_ylabel("Average PM10 (µg/m³)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 6: Weather vs Pollution Relationships

# %% [markdown]
# ### Viz 1: Temperature vs PM2.5

# %%
# Scatter plot: Temperature vs PM2.5
sns.jointplot(x='Temperature', y='PM25', data=Weather_Data, kind='scatter', height=7, color='g')

# Adjust title & position
plt.suptitle("Temperature vs PM2.5", y=1.02)
plt.show()

# %% [markdown]
# ### Viz 2: Effect of Wind Speed on Pollution (Dispersion Effect)
# ### Insight: Higher wind speed helps reduce pollution levels.

# %%
# Wind speed vs PM2.5
sns.jointplot(x='WindSpeed', y='PM25', data=Weather_Data, kind='scatter', height=7, color='cyan')

# Adjust the title position
plt.suptitle("Wind Speed vs PM2.5", y=1.02)
plt.show()

# %% [markdown]
# ### Viz 3: Humidity vs PM2.5
# - Shows how moisture affects pollution accumulation
# - Very relevant for haze/mist conditions

# %%
plt.figure(figsize=(8,6))
sns.jointplot(
    data=Weather_Data,
    kind='hex',
    x='Humidity',
    y='PM25',
    height=7,
    color='LightSeaGreen'
)

plt.suptitle('Effect of Humidity on PM2.5 Levels', y=1.02)
plt.xlabel('Humidity (%)')
plt.ylabel('PM2.5 (µg/m³)')
plt.show()

# %% [markdown]
# ### Viz 4: Overall Relationship between Temperature and PM2.5

# %%
sns.regplot(
    data=Weather_Data,
    x='PM25',
    y='Temperature',
    scatter_kws={'alpha':0.5},
    line_kws={'color':'red'}
)
plt.title('Overall Relationship between Temperature and PM2.5')
plt.xlabel('PM2.5 (µg/m³)')
plt.ylabel('Temperature (°C)')
plt.show()

# %% [markdown]
# ### Viz 5: PM2.5 vs Temperature by City

# %%
g = sns.FacetGrid(
    Weather_Data,
    col='City',
    col_wrap=4,
    height=3,
)

g.map(sns.scatterplot, 'PM25', 'Temperature')
g.fig.suptitle('PM2.5 vs Temperature by City', y=1.05)
plt.show()

# %% [markdown]
# ### Viz 6: PM10 vs Temperature by City

# %%
g = sns.FacetGrid(
    Weather_Data,
    col='City',
    col_wrap=4,
    height=3
)

g.map(sns.scatterplot, 'PM10', 'Temperature')
g.fig.suptitle('PM10 vs Temperature by City', y=1.05)
plt.show()

# %% [markdown]
# ### Viz 7: Visibility vs PM2.5 (Smog Identification)
# ### Insight: High PM2.5 severely reduces visibility → smog conditions.

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=Weather_Data,
    x='PM25',
    y='Visibility', 
    alpha=0.5, 
    color="goldenrod"
)
plt.title('Impact of PM2.5 on Visibility')
plt.xlabel('PM2.5 (µg/m³)')
plt.ylabel('Visibility')
plt.show()

# %%
Weather_Data.head()
# Out:
#             UpdatedAt Country CountryCode    State StateCode       City  \
# 0 2025-06-01 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 1 2025-06-02 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 2 2025-06-03 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 3 2025-06-04 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
# 4 2025-06-05 12:00:00   India          IN  Gujarat        GJ  Ahmedabad
#
#     CityID  Latitude  Longitude WeatherCondition  ...     NO    NO2     O3  \
# 0  1279233   23.0225    72.5714             Rain  ...   4.43  38.19  70.04
# 1  1279233   23.0225    72.5714             Rain  ...   8.74  20.16  42.95
# 2  1279233   23.0225    72.5714     Thunderstorm  ...  14.69  20.85  31.69
# 3  1279233   23.0225    72.5714            Clear  ...  16.81  54.36  56.80
# 4  1279233   23.0225    72.5714           Clouds  ...  15.13   9.56  16.31
#
#      SO2   PM25   PM10    NH3           CreatedAt        Date  AQI_Category
# 0  10.91  36.54  53.71   3.60 2025-06-01 12:00:00  2025-06-01  Satisfactory
# 1   7.57  48.00  68.64  14.81 2025-06-02 12:00:00  2025-06-02  Satisfactory
# 2   9.73  37.52  53.28  13.21 2025-06-03 12:00:00  2025-06-03  Satisfactory
# 3   4.64  63.84  91.93  14.59 2025-06-04 12:00:00  2025-06-04      Moderate
# 4  20.10  57.96  89.84  10.07 2025-06-05 12:00:00  2025-06-05      Moderate
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Step 5: AQI vs. Pollution analysis

# %% [markdown]
# ### Viz 1: % Of Very Poor & Severe proportion
# ### Insight : “Which cities most frequently experience bad air quality?”

# %%
# # See how many times Kolkata appears in the dataset
# kolkata_count = Weather_Data[Weather_Data['City'] == 'Kolkata'].shape[0]
# print(f"Kolkata appears {kolkata_count} times in the dataset.")

# # Same for darjeeling
# darjeeling_count = Weather_Data[Weather_Data['City'] == 'Darjeeling'].shape[0]
# print(f"Darjeeling appears {darjeeling_count} times in the dataset.")

# %%
MIN_DAYS = 200

city_counts = Weather_Data["City"].value_counts()
valid_cities = city_counts[city_counts >= MIN_DAYS].index

df_valid = Weather_Data[Weather_Data["City"].isin(valid_cities)]

# %%
Weather_Data['AQI_Category'].value_counts()
# Out:
# AQI_Category
# Moderate        3108
# Satisfactory    2889
# Good             969
# Poor             525
# Very Poor        109
# Name: count, dtype: int64

# %%
# Proportion of Poor / Severe AQI Days means
poor_severe = ["Very Poor", "Severe"]

city_ratio = (
    df_valid["AQI_Category"]
    .isin(poor_severe)
    .groupby(df_valid["City"])
    .mean()
    .sort_values(ascending=False)
    .head(5)
)

# %%
plt.figure(figsize=(10,6))
city_ratio.sort_values().plot(kind="barh", color='salmon')
plt.xlabel("Proportion of Very Poor/Severe AQI Records", y=1.2)
plt.title("Proportion of Very Poor & Severe AQI Records by City (Cities with ≥ 200 AQI records)")
plt.tight_layout()
plt.show()

# %%
# Find out Top 10 cities have highest AQI
city_aqi = (
    Weather_Data.groupby('City', as_index=False)['AQI']
    .mean()
    .sort_values(by='AQI', ascending=False)
    .head(10)
)

plt.figure(figsize=(10,6))
sns.barplot(x='AQI', y='City', data=city_aqi, palette='RdYlGn')
plt.title("Top 10 Cities by Average AQI", fontsize=14, y=1.02)
plt.xlabel("Average AQI")
plt.ylabel("City Name")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\kundu\AppData\Local\Temp\ipykernel_1276\1291824755.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='AQI', y='City', data=city_aqi, palette='RdYlGn')

# %% [markdown]
# ### Viz 2: Relationship between PM2.5 and AQI Category

# %%
plt.figure(figsize=(8,6))
sns.barplot(
    data=Weather_Data,
    x= 'AQI_Category',
    y= 'PM25',
    hue='AQI_Category',
    legend=True
)

plt.title('Relationship between PM2.5 and AQI Category')
plt.xlabel('AQI Category')
plt.ylabel('PM2.5 (µg/m³)')
plt.show()

# %%
# Final AQI vs Temperature
plt.figure(figsize=(15,6))
sns.jointplot(
    data=Weather_Data,
    x='AQI',
    y='Temperature',
    hue='AQI_Category',
    palette='Set2'
)

plt.title('Relationship between Temperature and AQI', y=1.25)
plt.xlabel('AQI')
plt.ylabel('Temperature (°C)')
plt.show()

# %%
# AQI Distribution by City
plt.figure(figsize=(12,8))
sns.boxplot(
    data=Weather_Data,
    x='AQI',
    y='City',
    palette='Set3'
)

plt.title('AQI Distribution by City')
plt.xlabel('AQI')
plt.ylabel('City')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\kundu\AppData\Local\Temp\ipykernel_1276\466973704.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# ## Extract & place the Updated Data to dedicated path

# %%
from pathlib import Path

# 1. Define distinct paths.
output_dir = Path("../Datasets")
file_path = output_dir / "../Datasets/Forecasting_Data.csv"
    
# 2. Ensure the dedicated output folder exists
output_dir.mkdir(parents=True, exist_ok=True)

# 3. Save the cleaned copy to your dedicated path
Weather_Data.to_csv(file_path, index=False)

print(f"Cleaned data saved safely at: {file_path}")
# Out:
# Cleaned data saved safely at: ..\Datasets\..\Datasets\Forecasting_Data.csv
